# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
! pip install -q kaggle
! mkdir ~/.kaggle
! cp /content/drive/MyDrive/kaggle.json ~/.kaggle/kaggle.json
! chmod 600 ~/.kaggle/kaggle.json

# %%
! kaggle datasets download delayedkarma/impressionist-classifier-data
! unzip impressionist-classifier-data.zip
# Out:
# Downloading impressionist-classifier-data.zip to /content
# 100% 2.19G/2.19G [01:53<00:00, 23.4MB/s]
# 100% 2.19G/2.19G [01:53<00:00, 20.7MB/s]
# Archive:  impressionist-classifier-data.zip
#   inflating: training/training/Cezanne/215457.jpg
#   inflating: training/training/Cezanne/215458.jpg
#   inflating: training/training/Cezanne/215459.jpg
#   inflating: training/training/Cezanne/215460.jpg
#   inflating: training/training/Cezanne/215462.jpg
#   inflating: training/training/Cezanne/215463.jpg
#   inflating: training/training/Cezanne/215466.jpg
#   inflating: training/training/Cezanne/215467.jpg
#   inflating: training/training/Cezanne/215468.jpg
#   inflating: training/training/Cezanne/215469.jpg
#   inflating: training/training/Cezanne/215470.jpg
#   inflating: training/training/Cezanne/215471.jpg
#   inflating: training/training/Cezanne/215473.jpg
#   inflating: training/training/Cezanne/215474.jpg
#   inflating: training/training/Cezanne/215475.jpg
#   inflating: training/training/Cezanne/215476.jpg
#   inflating: training/training/Cezanne/215477.jpg
#   inflating: training/training/Cezanne/215478.jpg
#   inflating: training/training/Cezanne/215479.jpg
#   inflating: training/training/Cezanne/215480.jpg
#   inflating: training/training/Cezanne/215481.jpg
#   inflating: training/training/Cezanne/215482.jpg
#   inflating: training/training/Cezanne/215483.jpg
#   inflating: training/training/Cezanne/215484.jpg
#   inflating: training/training/Cezanne/215485.jpg
#   inflating: training/training/Cezanne/215486.jpg
#   inflating: training/training/Cezanne/215487.jpg
#   inflating: training/training/Cezanne/215488.jpg
#   inflating: training/training/Cezanne/215489.jpg
#   inflating: training/training/Cezanne/215491.jpg
#   inflating: training/training/Cezanne/215492.jpg
#   inflating: training/training/Cezanne/215493.jpg
#   inflating: training/training/Cezanne/215496.jpg
#   inflating: training/training/Cezanne/215497.jpg
#   inflating: training/training/Cezanne/215500.jpg
#   inflating: training/training/Cezanne/215501.jpg
#   inflating: training/training/Cezanne/215504.jpg
#   inflating: training/training/Cezanne/215507.jpg
#   inflating: training/training/Cezanne/215509.jpg
#   inflating: training/training/Cezanne/215510.jpg
#   inflating: training/training/Cezanne/215511.jpg
#   inflating: training/training/Cezanne/215515.jpg
#   inflating: training/training/Cezanne/215516.jpg
#   inflating: training/training/Cezanne/215517.jpg
#   inflating: training/training/Cezanne/215518.jpg
#   inflating: training/training/Cezanne/215519.jpg
#   inflating: training/training/Cezanne/215520.jpg
#   inflating: training/training/Cezanne/215522.jpg
#   inflating: training/training/Cezanne/215523.jpg
#   inflating: training/training/Cezanne/215524.jpg
#   inflating: training/training/Cezanne/215525.jpg
#   inflating: training/training/Cezanne/215527.jpg
#   inflating: training/training/Cezanne/215528.jpg
#   inflating: training/training/Cezanne/215530.jpg
#   inflating: training/training/Cezanne/215531.jpg
#   inflating: training/training/Cezanne/215534.jpg
#   inflating: training/training/Cezanne/215535.jpg
#   inflating: training/training/Cezanne/215536.jpg
#   inflating: training/training/Cezanne/215538.jpg
#   inflating: training/training/Cezanne/215540.jpg
#   inflating: training/training/Cezanne/215541.jpg
#   inflating: training/training/Cezanne/215542.jpg
#   inflating: training/training/Cezanne/215543.jpg
#   inflating: training/training/Cezanne/215544.jpg
#   inflating: training/training/Cezanne/215545.jpg
#   inflating: training/training/Cezanne/215546.jpg
#   inflating: training/training/Cezanne/215548.jpg
#   inflating: training/training/Cezanne/215549.jpg
#   inflating: training/training/Cezanne/215551.jpg
#   inflating: training/training/Cezanne/215552.jpg
#   inflating: training/training/Cezanne/215556.jpg
#   inflating: training/training/Cezanne/215560.jpg
#   inflating: training/training/Cezanne/215564.jpg
#   inflating: training/training/Cezanne/215565.jpg
#   inflating: training/training/Cezanne/215566.jpg
#   inflating: training/training/Cezanne/215568.jpg
#   inflating: training/training/Cezanne/215571.jpg
#   inflating: training/training/Cezanne/215572.jpg
#   inflating: training/training/Cezanne/215573.jpg
#   inflating: training/training/Cezanne/215574.jpg
#   inflating: training/training/Cezanne/215575.jpg
#   inflating: training/training/Cezanne/215576.jpg
#   inflating: training/training/Cezanne/215577.jpg
#   inflating: training/training/Cezanne/215578.jpg
#   inflating: training/training/Cezanne/215579.jpg
#   inflating: training/training/Cezanne/215581.jpg
#   inflating: training/training/Cezanne/215582.jpg
#   inflating: training/training/Cezanne/215583.jpg
#   inflating: training/training/Cezanne/215585.jpg
#   inflating: training/training/Cezanne/215586.jpg
#   inflating: training/training/Cezanne/215589.jpg
#   inflating: training/training/Cezanne/215590.jpg
#   inflating: training/training/Cezanne/215595.jpg
#   inflating: training/training/Cezanne/215596.jpg
#   inflating: training/training/Cezanne/215598.jpg
#   inflating: training/training/Cezanne/215600.jpg
#   inflating: training/training/Cezanne/215601.jpg
#   inflating: training/training/Cezanne/215602.jpg
#   inflating: training/training/Cezanne/215603.jpg
#   inflating: training/training/Cezanne/215604.jpg
#   inflating: training/training/Cezanne/215605.jpg
#   inflating: training/training/Cezanne/215607.jpg
#   inflating: training/training/Cezanne/215609.jpg
#   inflating: training/training/Cezanne/215613.jpg
#   inflating: training/training/Cezanne/215615.jpg
#   inflating: training/training/Cezanne/215616.jpg
#   inflating: training/training/Cezanne/215617.jpg
#   inflating: training/training/Cezanne/215619.jpg
#   inflating: training/training/Cezanne/215620.jpg
#   inflating: training/training/Cezanne/215621.jpg
#   inflating: training/training/Cezanne/215622.jpg
#   inflating: training/training/Cezanne/215624.jpg
#   inflating: training/training/Cezanne/215625.jpg
#   inflating: training/training/Cezanne/215626.jpg
#   inflating: training/training/Cezanne/215627.jpg
#   inflating: training/training/Cezanne/215629.jpg
#   inflating: training/training/Cezanne/215630.jpg
#   inflating: training/training/Cezanne/215633.jpg
#   inflating: training/training/Cezanne/215634.jpg
#   inflating: training/training/Cezanne/215635.jpg
#   inflating: training/training/Cezanne/215636.jpg
#   inflating: training/training/Cezanne/215639.jpg
#   inflating: training/training/Cezanne/215641.jpg
#   inflating: training/training/Cezanne/215642.jpg
#   inflating: training/training/Cezanne/215643.jpg
#   inflating: training/training/Cezanne/215644.jpg
#   inflating: training/training/Cezanne/215645.jpg
#   inflating: training/training/Cezanne/215646.jpg
#   inflating: training/training/Cezanne/215647.jpg
#   inflating: training/training/Cezanne/215648.jpg
#   inflating: training/training/Cezanne/215650.jpg
#   inflating: training/training/Cezanne/215651.jpg
#   inflating: training/training/Cezanne/215652.jpg
#   inflating: training/training/Cezanne/215653.jpg
#   inflating: training/training/Cezanne/215654.jpg
#   inflating: training/training/Cezanne/215655.jpg
#   inflating: training/training/Cezanne/215656.jpg
#   inflating: training/training/Cezanne/215659.jpg
#   inflating: training/training/Cezanne/215660.jpg
#   inflating: training/training/Cezanne/215661.jpg
#   inflating: training/training/Cezanne/215662.jpg
#   inflating: training/training/Cezanne/215663.jpg
#   inflating: training/training/Cezanne/215664.jpg
#   inflating: training/training/Cezanne/215665.jpg
#   inflating: training/training/Cezanne/215670.jpg
#   inflating: training/training/Cezanne/215671.jpg
#   inflating: training/training/Cezanne/215672.jpg
#   inflating: training/training/Cezanne/215673.jpg
#   inflating: training/training/Cezanne/215674.jpg
#   inflating: training/training/Cezanne/215675.jpg
#   inflating: training/training/Cezanne/215677.jpg
#   inflating: training/training/Cezanne/215678.jpg
#   inflating: training/training/Cezanne/215679.jpg
#   inflating: training/training/Cezanne/215680.jpg
#   inflating: training/training/Cezanne/215681.jpg
#   inflating: training/training/Cezanne/215682.jpg
#   inflating: training/training/Cezanne/215683.jpg
#   inflating: training/training/Cezanne/215684.jpg
#   inflating: training/training/Cezanne/215688.jpg
#   inflating: training/training/Cezanne/215689.jpg
#   inflating: training/training/Cezanne/215690.jpg
#   inflating: training/training/Cezanne/215693.jpg
#   inflating: training/training/Cezanne/215698.jpg
#   inflating: training/training/Cezanne/215700.jpg
#   inflating: training/training/Cezanne/215702.jpg
#   inflating: training/training/Cezanne/215703.jpg
#   inflating: training/training/Cezanne/215706.jpg
#   inflating: training/training/Cezanne/215709.jpg
#   inflating: training/training/Cezanne/215710.jpg
#   inflating: training/training/Cezanne/215711.jpg
#   inflating: training/training/Cezanne/215719.jpg
#   inflating: training/training/Cezanne/215721.jpg
#   inflating: training/training/Cezanne/215722.jpg
#   inflating: training/training/Cezanne/215724.jpg
#   inflating: training/training/Cezanne/215729.jpg
#   inflating: training/training/Cezanne/215730.jpg
#   inflating: training/training/Cezanne/215732.jpg
#   inflating: training/training/Cezanne/215733.jpg
#   inflating: training/training/Cezanne/215734.jpg
#   inflating: training/training/Cezanne/215735.jpg
#   inflating: training/training/Cezanne/215736.jpg
#   inflating: training/training/Cezanne/215737.jpg
#   inflating: training/training/Cezanne/215739.jpg
#   inflating: training/training/Cezanne/215740.jpg
#   inflating: training/training/Cezanne/215741.jpg
#   inflating: training/training/Cezanne/215743.jpg
#   inflating: training/training/Cezanne/215744.jpg
#   inflating: training/training/Cezanne/215746.jpg
#   inflating: training/training/Cezanne/215747.jpg
#   inflating: training/training/Cezanne/215748.jpg
#   inflating: training/training/Cezanne/215749.jpg
#   inflating: training/training/Cezanne/215750.jpg
#   inflating: training/training/Cezanne/215753.jpg
#   inflating: training/training/Cezanne/215755.jpg
#   inflating: training/training/Cezanne/215757.jpg
#   inflating: training/training/Cezanne/215758.jpg
#   inflating: training/training/Cezanne/215759.jpg
#   inflating: training/training/Cezanne/215761.jpg
#   inflating: training/training/Cezanne/215762.jpg
#   inflating: training/training/Cezanne/215763.jpg
#   inflating: training/training/Cezanne/215764.jpg
#   inflating: training/training/Cezanne/215765.jpg
#   inflating: training/training/Cezanne/215766.jpg
#   inflating: training/training/Cezanne/215767.jpg
#   inflating: training/training/Cezanne/215768.jpg
#   inflating: training/training/Cezanne/215769.jpg
#   inflating: training/training/Cezanne/215770.jpg
#   inflating: training/training/Cezanne/215771.jpg
#   inflating: training/training/Cezanne/215772.jpg
#   inflating: training/training/Cezanne/215777.jpg
#   inflating: training/training/Cezanne/215778.jpg
#   inflating: training/training/Cezanne/215780.jpg
#   inflating: training/training/Cezanne/215781.jpg
#   inflating: training/training/Cezanne/215782.jpg
#   inflating: training/training/Cezanne/215783.jpg
#   inflating: training/training/Cezanne/215784.jpg
#   inflating: training/training/Cezanne/215785.jpg
#   inflating: training/training/Cezanne/215787.jpg
#   inflating: training/training/Cezanne/215788.jpg
#   inflating: training/training/Cezanne/215790.jpg
#   inflating: training/training/Cezanne/215791.jpg
#   inflating: training/training/Cezanne/215797.jpg
#   inflating: training/training/Cezanne/215798.jpg
#   inflating: training/training/Cezanne/215800.jpg
#   inflating: training/training/Cezanne/215801.jpg
#   inflating: training/training/Cezanne/215802.jpg
#   inflating: training/training/Cezanne/215803.jpg
#   inflating: training/training/Cezanne/215805.jpg
#   inflating: training/training/Cezanne/215807.jpg
#   inflating: training/training/Cezanne/215809.jpg
#   inflating: training/training/Cezanne/215812.jpg
#   inflating: training/training/Cezanne/215815.jpg
#   inflating: training/training/Cezanne/215816.jpg
#   inflating: training/training/Cezanne/215818.jpg
#   inflating: training/training/Cezanne/215819.jpg
#   inflating: training/training/Cezanne/215820.jpg
#   inflating: training/training/Cezanne/215823.jpg
#   inflating: training/training/Cezanne/215824.jpg
#   inflating: training/training/Cezanne/215825.jpg
#   inflating: training/training/Cezanne/215826.jpg
#   inflating: training/training/Cezanne/215827.jpg
#   inflating: training/training/Cezanne/215829.jpg
#   inflating: training/training/Cezanne/215830.jpg
#   inflating: training/training/Cezanne/215831.jpg
#   inflating: training/training/Cezanne/215833.jpg
#   inflating: training/training/Cezanne/215834.jpg
#   inflating: training/training/Cezanne/215835.jpg
#   inflating: training/training/Cezanne/215838.jpg
#   inflating: training/training/Cezanne/215840.jpg
#   inflating: training/training/Cezanne/215842.jpg
#   inflating: training/training/Cezanne/215843.jpg
#   inflating: training/training/Cezanne/215844.jpg
#   inflating: training/training/Cezanne/215845.jpg
#   inflating: training/training/Cezanne/215847.jpg
#   inflating: training/training/Cezanne/215848.jpg
#   inflating: training/training/Cezanne/215850.jpg
#   inflating: training/training/Cezanne/215851.jpg
#   inflating: training/training/Cezanne/215852.jpg
#   inflating: training/training/Cezanne/215853.jpg
#   inflating: training/training/Cezanne/215854.jpg
#   inflating: training/training/Cezanne/215856.jpg
#   inflating: training/training/Cezanne/215857.jpg
#   inflating: training/training/Cezanne/215858.jpg
#   inflating: training/training/Cezanne/215859.jpg
#   inflating: training/training/Cezanne/215860.jpg
#   inflating: training/training/Cezanne/215861.jpg
#   inflating: training/training/Cezanne/215862.jpg
#   inflating: training/training/Cezanne/215863.jpg
#   inflating: training/training/Cezanne/215864.jpg
#   inflating: training/training/Cezanne/215865.jpg
#   inflating: training/training/Cezanne/215866.jpg
#   inflating: training/training/Cezanne/215867.jpg
#   inflating: training/training/Cezanne/215868.jpg
#   inflating: training/training/Cezanne/215869.jpg
#   inflating: training/training/Cezanne/215870.jpg
#   inflating: training/training/Cezanne/215871.jpg
#   inflating: training/training/Cezanne/215874.jpg
#   inflating: training/training/Cezanne/215875.jpg
#   inflating: training/training/Cezanne/215876.jpg
#   inflating: training/training/Cezanne/215877.jpg
#   inflating: training/training/Cezanne/215878.jpg
#   inflating: training/training/Cezanne/215880.jpg
#   inflating: training/training/Cezanne/215882.jpg
#   inflating: training/training/Cezanne/215883.jpg
#   inflating: training/training/Cezanne/215884.jpg
#   inflating: training/training/Cezanne/215886.jpg
#   inflating: training/training/Cezanne/215887.jpg
#   inflating: training/training/Cezanne/215888.jpg
#   inflating: training/training/Cezanne/215890.jpg
#   inflating: training/training/Cezanne/215893.jpg
#   inflating: training/training/Cezanne/215894.jpg
#   inflating: training/training/Cezanne/215896.jpg
#   inflating: training/training/Cezanne/215897.jpg
#   inflating: training/training/Cezanne/215899.jpg
#   inflating: training/training/Cezanne/215901.jpg
#   inflating: training/training/Cezanne/215902.jpg
#   inflating: training/training/Cezanne/215903.jpg
#   inflating: training/training/Cezanne/215904.jpg
#   inflating: training/training/Cezanne/215905.jpg
#   inflating: training/training/Cezanne/215907.jpg
#   inflating: training/training/Cezanne/215908.jpg
#   inflating: training/training/Cezanne/215909.jpg
#   inflating: training/training/Cezanne/215910.jpg
#   inflating: training/training/Cezanne/215911.jpg
#   inflating: training/training/Cezanne/215912.jpg
#   inflating: training/training/Cezanne/215914.jpg
#   inflating: training/training/Cezanne/215915.jpg
#   inflating: training/training/Cezanne/215916.jpg
#   inflating: training/training/Cezanne/215917.jpg
#   inflating: training/training/Cezanne/215918.jpg
#   inflating: training/training/Cezanne/215919.jpg
#   inflating: training/training/Cezanne/215920.jpg
#   inflating: training/training/Cezanne/215921.jpg
#   inflating: training/training/Cezanne/215924.jpg
#   inflating: training/training/Cezanne/215926.jpg
#   inflating: training/training/Cezanne/215927.jpg
#   inflating: training/training/Cezanne/215928.jpg
#   inflating: training/training/Cezanne/215930.jpg
#   inflating: training/training/Cezanne/215932.jpg
#   inflating: training/training/Cezanne/215933.jpg
#   inflating: training/training/Cezanne/215935.jpg
#   inflating: training/training/Cezanne/215936.jpg
#   inflating: training/training/Cezanne/215937.jpg
#   inflating: training/training/Cezanne/215938.jpg
#   inflating: training/training/Cezanne/215939.jpg
#   inflating: training/training/Cezanne/215941.jpg
#   inflating: training/training/Cezanne/215942.jpg
#   inflating: training/training/Cezanne/215943.jpg
#   inflating: training/training/Cezanne/215945.jpg
#   inflating: training/training/Cezanne/215946.jpg
#   inflating: training/training/Cezanne/215947.jpg
#   inflating: training/training/Cezanne/215949.jpg
#   inflating: training/training/Cezanne/215951.jpg
#   inflating: training/training/Cezanne/215952.jpg
#   inflating: training/training/Cezanne/215953.jpg
#   inflating: training/training/Cezanne/215954.jpg
#   inflating: training/training/Cezanne/215956.jpg
#   inflating: training/training/Cezanne/215957.jpg
#   inflating: training/training/Cezanne/215958.jpg
#   inflating: training/training/Cezanne/215959.jpg
#   inflating: training/training/Cezanne/215961.jpg
#   inflating: training/training/Cezanne/215966.jpg
#   inflating: training/training/Cezanne/215967.jpg
#   inflating: training/training/Cezanne/215968.jpg
#   inflating: training/training/Cezanne/215969.jpg
#   inflating: training/training/Cezanne/215970.jpg
#   inflating: training/training/Cezanne/215972.jpg
#   inflating: training/training/Cezanne/215974.jpg
#   inflating: training/training/Cezanne/215977.jpg
#   inflating: training/training/Cezanne/215978.jpg
#   inflating: training/training/Cezanne/215981.jpg
#   inflating: training/training/Cezanne/215982.jpg
#   inflating: training/training/Cezanne/215983.jpg
#   inflating: training/training/Cezanne/215984.jpg
#   inflating: training/training/Cezanne/215987.jpg
#   inflating: training/training/Cezanne/215988.jpg
#   inflating: training/training/Cezanne/215989.jpg
#   inflating: training/training/Cezanne/215991.jpg
#   inflating: training/training/Cezanne/215992.jpg
#   inflating: training/training/Cezanne/215993.jpg
#   inflating: training/training/Cezanne/215994.jpg
#   inflating: training/training/Cezanne/215996.jpg
#   inflating: training/training/Cezanne/215997.jpg
#   inflating: training/training/Cezanne/215998.jpg
#   inflating: training/training/Cezanne/215999.jpg
#   inflating: training/training/Cezanne/216001.jpg
#   inflating: training/training/Cezanne/216003.jpg
#   inflating: training/training/Cezanne/216004.jpg
#   inflating: training/training/Cezanne/216005.jpg
#   inflating: training/training/Cezanne/216006.jpg
#   inflating: training/training/Cezanne/216007.jpg
#   inflating: training/training/Cezanne/216008.jpg
#   inflating: training/training/Cezanne/216009.jpg
#   inflating: training/training/Cezanne/216010.jpg
#   inflating: training/training/Cezanne/216011.jpg
#   inflating: training/training/Cezanne/216013.jpg
#   inflating: training/training/Cezanne/216015.jpg
#   inflating: training/training/Cezanne/216018.jpg
#   inflating: training/training/Cezanne/216019.jpg
#   inflating: training/training/Cezanne/216020.jpg
#   inflating: training/training/Cezanne/216021.jpg
#   inflating: training/training/Cezanne/216022.jpg
#   inflating: training/training/Cezanne/216023.jpg
#   inflating: training/training/Cezanne/216025.jpg
#   inflating: training/training/Cezanne/216027.jpg
#   inflating: training/training/Cezanne/216029.jpg
#   inflating: training/training/Cezanne/216030.jpg
#   inflating: training/training/Cezanne/216031.jpg
#   inflating: training/training/Cezanne/216032.jpg
#   inflating: training/training/Cezanne/216034.jpg
#   inflating: training/training/Cezanne/216035.jpg
#   inflating: training/training/Cezanne/216036.jpg
#   inflating: training/training/Cezanne/216037.jpg
#   inflating: training/training/Cezanne/216038.jpg
#   inflating: training/training/Cezanne/216039.jpg
#   inflating: training/training/Cezanne/216040.jpg
#   inflating: training/training/Cezanne/319489.jpg
#   inflating: training/training/Cezanne/337093.jpg
#   inflating: training/training/Cezanne/9223372032559845328.jpg
#   inflating: training/training/Degas/213255.jpg
#   inflating: training/training/Degas/213256.jpg
#   inflating: training/training/Degas/213257.jpg
#   inflating: training/training/Degas/213260.jpg
#   inflating: training/training/Degas/213261.jpg
#   inflating: training/training/Degas/213262.jpg
#   inflating: training/training/Degas/213264.jpg
#   inflating: training/training/Degas/213265.jpg
#   inflating: training/training/Degas/213266.jpg
#   inflating: training/training/Degas/213267.jpg
#   inflating: training/training/Degas/213268.jpg
#   inflating: training/training/Degas/213269.jpg
#   inflating: training/training/Degas/213270.jpg
#   inflating: training/training/Degas/213272.jpg
#   inflating: training/training/Degas/213273.jpg
#   inflating: training/training/Degas/213274.jpg
#   inflating: training/training/Degas/213275.jpg
#   inflating: training/training/Degas/213277.jpg
#   inflating: training/training/Degas/213279.jpg
#   inflating: training/training/Degas/213280.jpg
#   inflating: training/training/Degas/213282.jpg
#   inflating: training/training/Degas/213286.jpg
#   inflating: training/training/Degas/213287.jpg
#   inflating: training/training/Degas/213288.jpg
#   inflating: training/training/Degas/213289.jpg
#   inflating: training/training/Degas/213292.jpg
#   inflating: training/training/Degas/213293.jpg
#   inflating: training/training/Degas/213294.jpg
#   inflating: training/training/Degas/213298.jpg
#   inflating: training/training/Degas/213299.jpg
#   inflating: training/training/Degas/213302.jpg
#   inflating: training/training/Degas/213303.jpg
#   inflating: training/training/Degas/213304.jpg
#   inflating: training/training/Degas/213306.jpg
#   inflating: training/training/Degas/213307.jpg
#   inflating: training/training/Degas/213310.jpg
#   inflating: training/training/Degas/213311.jpg
#   inflating: training/training/Degas/213313.jpg
#   inflating: training/training/Degas/213314.jpg
#   inflating: training/training/Degas/213320.jpg
#   inflating: training/training/Degas/213321.jpg
#   inflating: training/training/Degas/213322.jpg
#   inflating: training/training/Degas/213323.jpg
#   inflating: training/training/Degas/213326.jpg
#   inflating: training/training/Degas/213327.jpg
#   inflating: training/training/Degas/213328.jpg
#   inflating: training/training/Degas/213329.jpg
#   inflating: training/training/Degas/213330.jpg
#   inflating: training/training/Degas/213331.jpg
#   inflating: training/training/Degas/213332.jpg
#   inflating: training/training/Degas/213333.jpg
#   inflating: training/training/Degas/213334.jpg
#   inflating: training/training/Degas/213335.jpg
#   inflating: training/training/Degas/213336.jpg
#   inflating: training/training/Degas/213339.jpg
#   inflating: training/training/Degas/213340.jpg
#   inflating: training/training/Degas/213341.jpg
#   inflating: training/training/Degas/213342.jpg
#   inflating: training/training/Degas/213345.jpg
#   inflating: training/training/Degas/213346.jpg
#   inflating: training/training/Degas/213347.jpg
#   inflating: training/training/Degas/213349.jpg
#   inflating: training/training/Degas/213351.jpg
#   inflating: training/training/Degas/213353.jpg
#   inflating: training/training/Degas/213356.jpg
#   inflating: training/training/Degas/213358.jpg
#   inflating: training/training/Degas/213359.jpg
#   inflating: training/training/Degas/213363.jpg
#   inflating: training/training/Degas/213365.jpg
#   inflating: training/training/Degas/213366.jpg
#   inflating: training/training/Degas/213367.jpg
#   inflating: training/training/Degas/213369.jpg
#   inflating: training/training/Degas/213370.jpg
#   inflating: training/training/Degas/213371.jpg
#   inflating: training/training/Degas/213373.jpg
#   inflating: training/training/Degas/213374.jpg
#   inflating: training/training/Degas/213375.jpg
#   inflating: training/training/Degas/213377.jpg
#   inflating: training/training/Degas/213378.jpg
#   inflating: training/training/Degas/213379.jpg
#   inflating: training/training/Degas/213381.jpg
#   inflating: training/training/Degas/213382.jpg
#   inflating: training/training/Degas/213383.jpg
#   inflating: training/training/Degas/213385.jpg
#   inflating: training/training/Degas/213386.jpg
#   inflating: training/training/Degas/213389.jpg
#   inflating: training/training/Degas/213391.jpg
#   inflating: training/training/Degas/213392.jpg
#   inflating: training/training/Degas/213394.jpg
#   inflating: training/training/Degas/213395.jpg
#   inflating: training/training/Degas/213396.jpg
#   inflating: training/training/Degas/213398.jpg
#   inflating: training/training/Degas/213399.jpg
#   inflating: training/training/Degas/213400.jpg
#   inflating: training/training/Degas/213403.jpg
#   inflating: training/training/Degas/213405.jpg
#   inflating: training/training/Degas/213406.jpg
#   inflating: training/training/Degas/213407.jpg
#   inflating: training/training/Degas/213408.jpg
#   inflating: training/training/Degas/213411.jpg
#   inflating: training/training/Degas/213412.jpg
#   inflating: training/training/Degas/213413.jpg
#   inflating: training/training/Degas/213414.jpg
#   inflating: training/training/Degas/213415.jpg
#   inflating: training/training/Degas/213416.jpg
#   inflating: training/training/Degas/213417.jpg
#   inflating: training/training/Degas/213420.jpg
#   inflating: training/training/Degas/213423.jpg
#   inflating: training/training/Degas/213424.jpg
#   inflating: training/training/Degas/213425.jpg
#   inflating: training/training/Degas/213426.jpg
#   inflating: training/training/Degas/213427.jpg
#   inflating: training/training/Degas/213428.jpg
#   inflating: training/training/Degas/213429.jpg
#   inflating: training/training/Degas/213431.jpg
#   inflating: training/training/Degas/213432.jpg
#   inflating: training/training/Degas/213433.jpg
#   inflating: training/training/Degas/213435.jpg
#   inflating: training/training/Degas/213437.jpg
#   inflating: training/training/Degas/213438.jpg
#   inflating: training/training/Degas/213441.jpg
#   inflating: training/training/Degas/213442.jpg
#   inflating: training/training/Degas/213443.jpg
#   inflating: training/training/Degas/213445.jpg
#   inflating: training/training/Degas/213448.jpg
#   inflating: training/training/Degas/213450.jpg
#   inflating: training/training/Degas/213452.jpg
#   inflating: training/training/Degas/213453.jpg
#   inflating: training/training/Degas/213457.jpg
#   inflating: training/training/Degas/213458.jpg
#   inflating: training/training/Degas/213459.jpg
#   inflating: training/training/Degas/213461.jpg
#   inflating: training/training/Degas/213462.jpg
#   inflating: training/training/Degas/213463.jpg
#   inflating: training/training/Degas/213464.jpg
#   inflating: training/training/Degas/213465.jpg
#   inflating: training/training/Degas/213467.jpg
#   inflating: training/training/Degas/213469.jpg
#   inflating: training/training/Degas/213470.jpg
#   inflating: training/training/Degas/213472.jpg
#   inflating: training/training/Degas/213473.jpg
#   inflating: training/training/Degas/213474.jpg
#   inflating: training/training/Degas/213476.jpg
#   inflating: training/training/Degas/213478.jpg
#   inflating: training/training/Degas/213482.jpg
#   inflating: training/training/Degas/213483.jpg
#   inflating: training/training/Degas/213485.jpg
#   inflating: training/training/Degas/213486.jpg
#   inflating: training/training/Degas/213487.jpg
#   inflating: training/training/Degas/213488.jpg
#   inflating: training/training/Degas/213491.jpg
#   inflating: training/training/Degas/213495.jpg
#   inflating: training/training/Degas/213496.jpg
#   inflating: training/training/Degas/213497.jpg
#   inflating: training/training/Degas/213498.jpg
#   inflating: training/training/Degas/213499.jpg
#   inflating: training/training/Degas/213500.jpg
#   inflating: training/training/Degas/213501.jpg
#   inflating: training/training/Degas/213503.jpg
#   inflating: training/training/Degas/213505.jpg
#   inflating: training/training/Degas/213506.jpg
#   inflating: training/training/Degas/213508.jpg
#   inflating: training/training/Degas/213509.jpg
#   inflating: training/training/Degas/213511.jpg
#   inflating: training/training/Degas/213512.jpg
#   inflating: training/training/Degas/213514.jpg
#   inflating: training/training/Degas/213515.jpg
#   inflating: training/training/Degas/213516.jpg
#   inflating: training/training/Degas/213520.jpg
#   inflating: training/training/Degas/213521.jpg
#   inflating: training/training/Degas/213522.jpg
#   inflating: training/training/Degas/213523.jpg
#   inflating: training/training/Degas/213524.jpg
#   inflating: training/training/Degas/213525.jpg
#   inflating: training/training/Degas/213526.jpg
#   inflating: training/training/Degas/213531.jpg
#   inflating: training/training/Degas/213532.jpg
#   inflating: training/training/Degas/213533.jpg
#   inflating: training/training/Degas/213535.jpg
#   inflating: training/training/Degas/213536.jpg
#   inflating: training/training/Degas/213537.jpg
#   inflating: training/training/Degas/213538.jpg
#   inflating: training/training/Degas/213539.jpg
#   inflating: training/training/Degas/213541.jpg
#   inflating: training/training/Degas/213542.jpg
#   inflating: training/training/Degas/213543.jpg
#   inflating: training/training/Degas/213544.jpg
#   inflating: training/training/Degas/213548.jpg
#   inflating: training/training/Degas/213549.jpg
#   inflating: training/training/Degas/213550.jpg
#   inflating: training/training/Degas/213553.jpg
#   inflating: training/training/Degas/213554.jpg
#   inflating: training/training/Degas/213556.jpg
#   inflating: training/training/Degas/213558.jpg
#   inflating: training/training/Degas/213570.jpg
#   inflating: training/training/Degas/213571.jpg
#   inflating: training/training/Degas/213572.jpg
#   inflating: training/training/Degas/213573.jpg
#   inflating: training/training/Degas/213574.jpg
#   inflating: training/training/Degas/213578.jpg
#   inflating: training/training/Degas/213582.jpg
#   inflating: training/training/Degas/213583.jpg
#   inflating: training/training/Degas/213584.jpg
#   inflating: training/training/Degas/213585.jpg
#   inflating: training/training/Degas/213586.jpg
#   inflating: training/training/Degas/213587.jpg
#   inflating: training/training/Degas/213589.jpg
#   inflating: training/training/Degas/213590.jpg
#   inflating: training/training/Degas/213591.jpg
#   inflating: training/training/Degas/213592.jpg
#   inflating: training/training/Degas/213594.jpg
#   inflating: training/training/Degas/213595.jpg
#   inflating: training/training/Degas/213597.jpg
#   inflating: training/training/Degas/213598.jpg
#   inflating: training/training/Degas/213599.jpg
#   inflating: training/training/Degas/213600.jpg
#   inflating: training/training/Degas/213601.jpg
#   inflating: training/training/Degas/213602.jpg
#   inflating: training/training/Degas/213604.jpg
#   inflating: training/training/Degas/213605.jpg
#   inflating: training/training/Degas/213607.jpg
#   inflating: training/training/Degas/213609.jpg
#   inflating: training/training/Degas/213612.jpg
#   inflating: training/training/Degas/213617.jpg
#   inflating: training/training/Degas/213618.jpg
#   inflating: training/training/Degas/213619.jpg
#   inflating: training/training/Degas/213620.jpg
#   inflating: training/training/Degas/213622.jpg
#   inflating: training/training/Degas/213623.jpg
#   inflating: training/training/Degas/213624.jpg
#   inflating: training/training/Degas/213625.jpg
#   inflating: training/training/Degas/213628.jpg
#   inflating: training/training/Degas/213629.jpg
#   inflating: training/training/Degas/213631.jpg
#   inflating: training/training/Degas/213632.jpg
#   inflating: training/training/Degas/213633.jpg
#   inflating: training/training/Degas/213634.jpg
#   inflating: training/training/Degas/213635.jpg
#   inflating: training/training/Degas/213636.jpg
#   inflating: training/training/Degas/213637.jpg
#   inflating: training/training/Degas/213638.jpg
#   inflating: training/training/Degas/213639.jpg
#   inflating: training/training/Degas/213640.jpg
#   inflating: training/training/Degas/213642.jpg
#   inflating: training/training/Degas/213644.jpg
#   inflating: training/training/Degas/213645.jpg
#   inflating: training/training/Degas/213647.jpg
#   inflating: training/training/Degas/213649.jpg
#   inflating: training/training/Degas/213651.jpg
#   inflating: training/training/Degas/213652.jpg
#   inflating: training/training/Degas/213654.jpg
#   inflating: training/training/Degas/213655.jpg
#   inflating: training/training/Degas/213657.jpg
#   inflating: training/training/Degas/213658.jpg
#   inflating: training/training/Degas/213659.jpg
#   inflating: training/training/Degas/213660.jpg
#   inflating: training/training/Degas/213661.jpg
#   inflating: training/training/Degas/213662.jpg
#   inflating: training/training/Degas/213663.jpg
#   inflating: training/training/Degas/213664.jpg
#   inflating: training/training/Degas/213665.jpg
#   inflating: training/training/Degas/213667.jpg
#   inflating: training/training/Degas/213668.jpg
#   inflating: training/training/Degas/213669.jpg
#   inflating: training/training/Degas/213672.jpg
#   inflating: training/training/Degas/213673.jpg
#   inflating: training/training/Degas/213674.jpg
#   inflating: training/training/Degas/213677.jpg
#   inflating: training/training/Degas/213678.jpg
#   inflating: training/training/Degas/213680.jpg
#   inflating: training/training/Degas/213681.jpg
#   inflating: training/training/Degas/213682.jpg
#   inflating: training/training/Degas/213683.jpg
#   inflating: training/training/Degas/213684.jpg
#   inflating: training/training/Degas/213686.jpg
#   inflating: training/training/Degas/213687.jpg
#   inflating: training/training/Degas/213688.jpg
#   inflating: training/training/Degas/213689.jpg
#   inflating: training/training/Degas/213690.jpg
#   inflating: training/training/Degas/213691.jpg
#   inflating: training/training/Degas/213692.jpg
#   inflating: training/training/Degas/213695.jpg
#   inflating: training/training/Degas/213697.jpg
#   inflating: training/training/Degas/213698.jpg
#   inflating: training/training/Degas/213701.jpg
#   inflating: training/training/Degas/213702.jpg
#   inflating: training/training/Degas/213703.jpg
#   inflating: training/training/Degas/213704.jpg
#   inflating: training/training/Degas/213705.jpg
#   inflating: training/training/Degas/213706.jpg
#   inflating: training/training/Degas/213707.jpg
#   inflating: training/training/Degas/213708.jpg
#   inflating: training/training/Degas/213709.jpg
#   inflating: training/training/Degas/213710.jpg
#   inflating: training/training/Degas/213714.jpg
#   inflating: training/training/Degas/213716.jpg
#   inflating: training/training/Degas/213717.jpg
#   inflating: training/training/Degas/213718.jpg
#   inflating: training/training/Degas/213722.jpg
#   inflating: training/training/Degas/213724.jpg
#   inflating: training/training/Degas/213725.jpg
#   inflating: training/training/Degas/213726.jpg
#   inflating: training/training/Degas/213727.jpg
#   inflating: training/training/Degas/213728.jpg
#   inflating: training/training/Degas/213731.jpg
#   inflating: training/training/Degas/213732.jpg
#   inflating: training/training/Degas/213735.jpg
#   inflating: training/training/Degas/213737.jpg
#   inflating: training/training/Degas/213739.jpg
#   inflating: training/training/Degas/213740.jpg
#   inflating: training/training/Degas/213743.jpg
#   inflating: training/training/Degas/213744.jpg
#   inflating: training/training/Degas/213745.jpg
#   inflating: training/training/Degas/213746.jpg
#   inflating: training/training/Degas/213747.jpg
#   inflating: training/training/Degas/213748.jpg
#   inflating: training/training/Degas/213750.jpg
#   inflating: training/training/Degas/213751.jpg
#   inflating: training/training/Degas/213752.jpg
#   inflating: training/training/Degas/213753.jpg
#   inflating: training/training/Degas/213754.jpg
#   inflating: training/training/Degas/213755.jpg
#   inflating: training/training/Degas/213757.jpg
#   inflating: training/training/Degas/213758.jpg
#   inflating: training/training/Degas/213759.jpg
#   inflating: training/training/Degas/213763.jpg
#   inflating: training/training/Degas/213767.jpg
#   inflating: training/training/Degas/213768.jpg
#   inflating: training/training/Degas/213769.jpg
#   inflating: training/training/Degas/213770.jpg
#   inflating: training/training/Degas/213771.jpg
#   inflating: training/training/Degas/213775.jpg
#   inflating: training/training/Degas/213776.jpg
#   inflating: training/training/Degas/213779.jpg
#   inflating: training/training/Degas/213780.jpg
#   inflating: training/training/Degas/213781.jpg
#   inflating: training/training/Degas/213784.jpg
#   inflating: training/training/Degas/213785.jpg
#   inflating: training/training/Degas/213786.jpg
#   inflating: training/training/Degas/213787.jpg
#   inflating: training/training/Degas/213788.jpg
#   inflating: training/training/Degas/213791.jpg
#   inflating: training/training/Degas/213792.jpg
#   inflating: training/training/Degas/213793.jpg
#   inflating: training/training/Degas/213795.jpg
#   inflating: training/training/Degas/213799.jpg
#   inflating: training/training/Degas/213800.jpg
#   inflating: training/training/Degas/213801.jpg
#   inflating: training/training/Degas/213802.jpg
#   inflating: training/training/Degas/213803.jpg
#   inflating: training/training/Degas/213804.jpg
#   inflating: training/training/Degas/213805.jpg
#   inflating: training/training/Degas/213806.jpg
#   inflating: training/training/Degas/213808.jpg
#   inflating: training/training/Degas/213809.jpg
#   inflating: training/training/Degas/213811.jpg
#   inflating: training/training/Degas/213813.jpg
#   inflating: training/training/Degas/213815.jpg
#   inflating: training/training/Degas/213816.jpg
#   inflating: training/training/Degas/213818.jpg
#   inflating: training/training/Degas/213819.jpg
#   inflating: training/training/Degas/213820.jpg
#   inflating: training/training/Degas/213821.jpg
#   inflating: training/training/Degas/213826.jpg
#   inflating: training/training/Degas/213828.jpg
#   inflating: training/training/Degas/213829.jpg
#   inflating: training/training/Degas/213830.jpg
#   inflating: training/training/Degas/213831.jpg
#   inflating: training/training/Degas/213832.jpg
#   inflating: training/training/Degas/213833.jpg
#   inflating: training/training/Degas/213834.jpg
#   inflating: training/training/Degas/213835.jpg
#   inflating: training/training/Degas/213838.jpg
#   inflating: training/training/Degas/213843.jpg
#   inflating: training/training/Degas/213844.jpg
#   inflating: training/training/Degas/213845.jpg
#   inflating: training/training/Degas/213847.jpg
#   inflating: training/training/Degas/213851.jpg
#   inflating: training/training/Degas/213853.jpg
#   inflating: training/training/Degas/213855.jpg
#   inflating: training/training/Degas/213856.jpg
#   inflating: training/training/Degas/213858.jpg
#   inflating: training/training/Degas/213862.jpg
#   inflating: training/training/Degas/213868.jpg
#   inflating: training/training/Degas/213871.jpg
#   inflating: training/training/Degas/213875.jpg
#   inflating: training/training/Degas/213876.jpg
#   inflating: training/training/Degas/213877.jpg
#   inflating: training/training/Degas/213878.jpg
#   inflating: training/training/Degas/213880.jpg
#   inflating: training/training/Degas/213882.jpg
#   inflating: training/training/Degas/213883.jpg
#   inflating: training/training/Degas/213886.jpg
#   inflating: training/training/Degas/213887.jpg
#   inflating: training/training/Degas/9223372032559810721.jpg
#   inflating: training/training/Degas/9223372032559833980.jpg
#   inflating: training/training/Degas/9223372032559838153.jpg
#   inflating: training/training/Degas/9223372032559843654.jpg
#   inflating: training/training/Gauguin/190448.jpg
#   inflating: training/training/Gauguin/190450.jpg
#   inflating: training/training/Gauguin/190452.jpg
#   inflating: training/training/Gauguin/190453.jpg
#   inflating: training/training/Gauguin/190455.jpg
#   inflating: training/training/Gauguin/190456.jpg
#   inflating: training/training/Gauguin/190457.jpg
#   inflating: training/training/Gauguin/190458.jpg
#   inflating: training/training/Gauguin/190459.jpg
#   inflating: training/training/Gauguin/190462.jpg
#   inflating: training/training/Gauguin/190465.jpg
#   inflating: training/training/Gauguin/190468.jpg
#   inflating: training/training/Gauguin/190469.jpg
#   inflating: training/training/Gauguin/190470.jpg
#   inflating: training/training/Gauguin/190472.jpg
#   inflating: training/training/Gauguin/190473.jpg
#   inflating: training/training/Gauguin/190474.jpg
#   inflating: training/training/Gauguin/190475.jpg
#   inflating: training/training/Gauguin/190478.jpg
#   inflating: training/training/Gauguin/190479.jpg
#   inflating: training/training/Gauguin/190480.jpg
#   inflating: training/training/Gauguin/190481.jpg
#   inflating: training/training/Gauguin/190482.jpg
#   inflating: training/training/Gauguin/190483.jpg
#   inflating: training/training/Gauguin/190484.jpg
#   inflating: training/training/Gauguin/190485.jpg
#   inflating: training/training/Gauguin/190487.jpg
#   inflating: training/training/Gauguin/190490.jpg
#   inflating: training/training/Gauguin/190492.jpg
#   inflating: training/training/Gauguin/190493.jpg
#   inflating: training/training/Gauguin/190496.jpg
#   inflating: training/training/Gauguin/190497.jpg
#   inflating: training/training/Gauguin/190498.jpg
#   inflating: training/training/Gauguin/190499.jpg
#   inflating: training/training/Gauguin/190500.jpg
#   inflating: training/training/Gauguin/190503.jpg
#   inflating: training/training/Gauguin/190504.jpg
#   inflating: training/training/Gauguin/190506.jpg
#   inflating: training/training/Gauguin/190507.jpg
#   inflating: training/training/Gauguin/190508.jpg
#   inflating: training/training/Gauguin/190509.jpg
#   inflating: training/training/Gauguin/190510.jpg
#   inflating: training/training/Gauguin/190512.jpg
#   inflating: training/training/Gauguin/190513.jpg
#   inflating: training/training/Gauguin/190514.jpg
#   inflating: training/training/Gauguin/190515.jpg
#   inflating: training/training/Gauguin/190516.jpg
#   inflating: training/training/Gauguin/190517.jpg
#   inflating: training/training/Gauguin/190518.jpg
#   inflating: training/training/Gauguin/190519.jpg
#   inflating: training/training/Gauguin/190520.jpg
#   inflating: training/training/Gauguin/190521.jpg
#   inflating: training/training/Gauguin/190522.jpg
#   inflating: training/training/Gauguin/190523.jpg
#   inflating: training/training/Gauguin/190524.jpg
#   inflating: training/training/Gauguin/190525.jpg
#   inflating: training/training/Gauguin/190526.jpg
#   inflating: training/training/Gauguin/190527.jpg
#   inflating: training/training/Gauguin/190529.jpg
#   inflating: training/training/Gauguin/190530.jpg
#   inflating: training/training/Gauguin/190531.jpg
#   inflating: training/training/Gauguin/190532.jpg
#   inflating: training/training/Gauguin/190533.jpg
#   inflating: training/training/Gauguin/190536.jpg
#   inflating: training/training/Gauguin/190538.jpg
#   inflating: training/training/Gauguin/190539.jpg
#   inflating: training/training/Gauguin/190540.jpg
#   inflating: training/training/Gauguin/190541.jpg
#   inflating: training/training/Gauguin/190542.jpg
#   inflating: training/training/Gauguin/190543.jpg
#   inflating: training/training/Gauguin/190545.jpg
#   inflating: training/training/Gauguin/190546.jpg
#   inflating: training/training/Gauguin/190547.jpg
#   inflating: training/training/Gauguin/190548.jpg
#   inflating: training/training/Gauguin/190549.jpg
#   inflating: training/training/Gauguin/190551.jpg
#   inflating: training/training/Gauguin/190552.jpg
#   inflating: training/training/Gauguin/190553.jpg
#   inflating: training/training/Gauguin/190554.jpg
#   inflating: training/training/Gauguin/190555.jpg
#   inflating: training/training/Gauguin/190556.jpg
#   inflating: training/training/Gauguin/190558.jpg
#   inflating: training/training/Gauguin/190559.jpg
#   inflating: training/training/Gauguin/190560.jpg
#   inflating: training/training/Gauguin/190561.jpg
#   inflating: training/training/Gauguin/190562.jpg
#   inflating: training/training/Gauguin/190565.jpg
#   inflating: training/training/Gauguin/190567.jpg
#   inflating: training/training/Gauguin/190568.jpg
#   inflating: training/training/Gauguin/190569.jpg
#   inflating: training/training/Gauguin/190571.jpg
#   inflating: training/training/Gauguin/190572.jpg
#   inflating: training/training/Gauguin/190574.jpg
#   inflating: training/training/Gauguin/190575.jpg
#   inflating: training/training/Gauguin/190576.jpg
#   inflating: training/training/Gauguin/190577.jpg
#   inflating: training/training/Gauguin/190578.jpg
#   inflating: training/training/Gauguin/190579.jpg
#   inflating: training/training/Gauguin/190580.jpg
#   inflating: training/training/Gauguin/190582.jpg
#   inflating: training/training/Gauguin/190583.jpg
#   inflating: training/training/Gauguin/190584.jpg
#   inflating: training/training/Gauguin/190585.jpg
#   inflating: training/training/Gauguin/190586.jpg
#   inflating: training/training/Gauguin/190587.jpg
#   inflating: training/training/Gauguin/190591.jpg
#   inflating: training/training/Gauguin/190592.jpg
#   inflating: training/training/Gauguin/190593.jpg
#   inflating: training/training/Gauguin/190594.jpg
#   inflating: training/training/Gauguin/190595.jpg
#   inflating: training/training/Gauguin/190596.jpg
#   inflating: training/training/Gauguin/190598.jpg
#   inflating: training/training/Gauguin/190599.jpg
#   inflating: training/training/Gauguin/190600.jpg
#   inflating: training/training/Gauguin/190601.jpg
#   inflating: training/training/Gauguin/190602.jpg
#   inflating: training/training/Gauguin/190604.jpg
#   inflating: training/training/Gauguin/190605.jpg
#   inflating: training/training/Gauguin/190607.jpg
#   inflating: training/training/Gauguin/190608.jpg
#   inflating: training/training/Gauguin/190609.jpg
#   inflating: training/training/Gauguin/190610.jpg
#   inflating: training/training/Gauguin/190612.jpg
#   inflating: training/training/Gauguin/190613.jpg
#   inflating: training/training/Gauguin/190614.jpg
#   inflating: training/training/Gauguin/190615.jpg
#   inflating: training/training/Gauguin/190616.jpg
#   inflating: training/training/Gauguin/190617.jpg
#   inflating: training/training/Gauguin/190618.jpg
#   inflating: training/training/Gauguin/190619.jpg
#   inflating: training/training/Gauguin/190620.jpg
#   inflating: training/training/Gauguin/190622.jpg
#   inflating: training/training/Gauguin/190623.jpg
#   inflating: training/training/Gauguin/190625.jpg
#   inflating: training/training/Gauguin/190626.jpg
#   inflating: training/training/Gauguin/190627.jpg
# ...
#   inflating: validation/validation/Renoir/218291.jpg
#   inflating: validation/validation/Renoir/218302.jpg
#   inflating: validation/validation/Renoir/218311.jpg
#   inflating: validation/validation/Renoir/218323.jpg
#   inflating: validation/validation/Renoir/218334.jpg
#   inflating: validation/validation/Renoir/218337.jpg
#   inflating: validation/validation/Renoir/218364.jpg
#   inflating: validation/validation/Renoir/218366.jpg
#   inflating: validation/validation/Renoir/218373.jpg
#   inflating: validation/validation/Renoir/218380.jpg
#   inflating: validation/validation/Renoir/218387.jpg
#   inflating: validation/validation/Renoir/218392.jpg
#   inflating: validation/validation/Renoir/218410.jpg
#   inflating: validation/validation/Renoir/218411.jpg
#   inflating: validation/validation/Renoir/218416.jpg
#   inflating: validation/validation/Renoir/218424.jpg
#   inflating: validation/validation/Renoir/218429.jpg
#   inflating: validation/validation/Renoir/218446.jpg
#   inflating: validation/validation/Renoir/218448.jpg
#   inflating: validation/validation/Renoir/218450.jpg
#   inflating: validation/validation/Renoir/218453.jpg
#   inflating: validation/validation/Renoir/218459.jpg
#   inflating: validation/validation/Renoir/218483.jpg
#   inflating: validation/validation/Renoir/218494.jpg
#   inflating: validation/validation/Renoir/218513.jpg
#   inflating: validation/validation/Renoir/218532.jpg
#   inflating: validation/validation/Renoir/218552.jpg
#   inflating: validation/validation/Renoir/218562.jpg
#   inflating: validation/validation/Renoir/218634.jpg
#   inflating: validation/validation/Renoir/218640.jpg
#   inflating: validation/validation/Renoir/218642.jpg
#   inflating: validation/validation/Renoir/218651.jpg
#   inflating: validation/validation/Renoir/218661.jpg
#   inflating: validation/validation/Renoir/218666.jpg
#   inflating: validation/validation/Renoir/218692.jpg
#   inflating: validation/validation/Renoir/218716.jpg
#   inflating: validation/validation/Renoir/218728.jpg
#   inflating: validation/validation/Renoir/218758.jpg
#   inflating: validation/validation/Renoir/218826.jpg
#   inflating: validation/validation/Renoir/218859.jpg
#   inflating: validation/validation/Renoir/218865.jpg
#   inflating: validation/validation/Renoir/218872.jpg
#   inflating: validation/validation/Renoir/218883.jpg
#   inflating: validation/validation/Renoir/218901.jpg
#   inflating: validation/validation/Renoir/218912.jpg
#   inflating: validation/validation/Renoir/218921.jpg
#   inflating: validation/validation/Renoir/218922.jpg
#   inflating: validation/validation/Renoir/218937.jpg
#   inflating: validation/validation/Renoir/218958.jpg
#   inflating: validation/validation/Renoir/218964.jpg
#   inflating: validation/validation/Renoir/218965.jpg
#   inflating: validation/validation/Renoir/218985.jpg
#   inflating: validation/validation/Renoir/219001.jpg
#   inflating: validation/validation/Renoir/219011.jpg
#   inflating: validation/validation/Renoir/219022.jpg
#   inflating: validation/validation/Renoir/219023.jpg
#   inflating: validation/validation/Renoir/219046.jpg
#   inflating: validation/validation/Renoir/219074.jpg
#   inflating: validation/validation/Renoir/219082.jpg
#   inflating: validation/validation/Renoir/219084.jpg
#   inflating: validation/validation/Renoir/219171.jpg
#   inflating: validation/validation/Renoir/219176.jpg
#   inflating: validation/validation/Renoir/219194.jpg
#   inflating: validation/validation/Renoir/219197.jpg
#   inflating: validation/validation/Renoir/219205.jpg
#   inflating: validation/validation/Renoir/219228.jpg
#   inflating: validation/validation/Renoir/219243.jpg
#   inflating: validation/validation/Renoir/219261.jpg
#   inflating: validation/validation/Renoir/219265.jpg
#   inflating: validation/validation/Renoir/219267.jpg
#   inflating: validation/validation/Renoir/219274.jpg
#   inflating: validation/validation/Renoir/219278.jpg
#   inflating: validation/validation/Renoir/219289.jpg
#   inflating: validation/validation/Renoir/219292.jpg
#   inflating: validation/validation/Renoir/219308.jpg
#   inflating: validation/validation/Renoir/219348.jpg
#   inflating: validation/validation/Renoir/219355.jpg
#   inflating: validation/validation/Renoir/219366.jpg
#   inflating: validation/validation/Renoir/219408.jpg
#   inflating: validation/validation/Renoir/219449.jpg
#   inflating: validation/validation/Renoir/219481.jpg
#   inflating: validation/validation/Renoir/219500.jpg
#   inflating: validation/validation/Renoir/219514.jpg
#   inflating: validation/validation/Renoir/219551.jpg
#   inflating: validation/validation/Renoir/219553.jpg
#   inflating: validation/validation/Renoir/219558.jpg
#   inflating: validation/validation/Renoir/219568.jpg
#   inflating: validation/validation/Renoir/219587.jpg
#   inflating: validation/validation/Sargent/265650.jpg
#   inflating: validation/validation/Sargent/265654.jpg
#   inflating: validation/validation/Sargent/265657.jpg
#   inflating: validation/validation/Sargent/265658.jpg
#   inflating: validation/validation/Sargent/265673.jpg
#   inflating: validation/validation/Sargent/265675.jpg
#   inflating: validation/validation/Sargent/265688.jpg
#   inflating: validation/validation/Sargent/265696.jpg
#   inflating: validation/validation/Sargent/265701.jpg
#   inflating: validation/validation/Sargent/265709.jpg
#   inflating: validation/validation/Sargent/265711.jpg
#   inflating: validation/validation/Sargent/265724.jpg
#   inflating: validation/validation/Sargent/265725.jpg
#   inflating: validation/validation/Sargent/265733.jpg
#   inflating: validation/validation/Sargent/265734.jpg
#   inflating: validation/validation/Sargent/265747.jpg
#   inflating: validation/validation/Sargent/265752.jpg
#   inflating: validation/validation/Sargent/265764.jpg
#   inflating: validation/validation/Sargent/265797.jpg
#   inflating: validation/validation/Sargent/265798.jpg
#   inflating: validation/validation/Sargent/265805.jpg
#   inflating: validation/validation/Sargent/265806.jpg
#   inflating: validation/validation/Sargent/265809.jpg
#   inflating: validation/validation/Sargent/265820.jpg
#   inflating: validation/validation/Sargent/265834.jpg
#   inflating: validation/validation/Sargent/265843.jpg
#   inflating: validation/validation/Sargent/265853.jpg
#   inflating: validation/validation/Sargent/265854.jpg
#   inflating: validation/validation/Sargent/265865.jpg
#   inflating: validation/validation/Sargent/265870.jpg
#   inflating: validation/validation/Sargent/265875.jpg
#   inflating: validation/validation/Sargent/265882.jpg
#   inflating: validation/validation/Sargent/265888.jpg
#   inflating: validation/validation/Sargent/265898.jpg
#   inflating: validation/validation/Sargent/265901.jpg
#   inflating: validation/validation/Sargent/265917.jpg
#   inflating: validation/validation/Sargent/265936.jpg
#   inflating: validation/validation/Sargent/265937.jpg
#   inflating: validation/validation/Sargent/265964.jpg
#   inflating: validation/validation/Sargent/265965.jpg
#   inflating: validation/validation/Sargent/265968.jpg
#   inflating: validation/validation/Sargent/265971.jpg
#   inflating: validation/validation/Sargent/265990.jpg
#   inflating: validation/validation/Sargent/265998.jpg
#   inflating: validation/validation/Sargent/266004.jpg
#   inflating: validation/validation/Sargent/266025.jpg
#   inflating: validation/validation/Sargent/266046.jpg
#   inflating: validation/validation/Sargent/266049.jpg
#   inflating: validation/validation/Sargent/266060.jpg
#   inflating: validation/validation/Sargent/266063.jpg
#   inflating: validation/validation/Sargent/266094.jpg
#   inflating: validation/validation/Sargent/266098.jpg
#   inflating: validation/validation/Sargent/266106.jpg
#   inflating: validation/validation/Sargent/266112.jpg
#   inflating: validation/validation/Sargent/266122.jpg
#   inflating: validation/validation/Sargent/266125.jpg
#   inflating: validation/validation/Sargent/266138.jpg
#   inflating: validation/validation/Sargent/266139.jpg
#   inflating: validation/validation/Sargent/266145.jpg
#   inflating: validation/validation/Sargent/266148.jpg
#   inflating: validation/validation/Sargent/266158.jpg
#   inflating: validation/validation/Sargent/266159.jpg
#   inflating: validation/validation/Sargent/266172.jpg
#   inflating: validation/validation/Sargent/266174.jpg
#   inflating: validation/validation/Sargent/266178.jpg
#   inflating: validation/validation/Sargent/266195.jpg
#   inflating: validation/validation/Sargent/266203.jpg
#   inflating: validation/validation/Sargent/266204.jpg
#   inflating: validation/validation/Sargent/266219.jpg
#   inflating: validation/validation/Sargent/266230.jpg
#   inflating: validation/validation/Sargent/266235.jpg
#   inflating: validation/validation/Sargent/266241.jpg
#   inflating: validation/validation/Sargent/266245.jpg
#   inflating: validation/validation/Sargent/266258.jpg
#   inflating: validation/validation/Sargent/266259.jpg
#   inflating: validation/validation/Sargent/266263.jpg
#   inflating: validation/validation/Sargent/266268.jpg
#   inflating: validation/validation/Sargent/266279.jpg
#   inflating: validation/validation/Sargent/266284.jpg
#   inflating: validation/validation/Sargent/266294.jpg
#   inflating: validation/validation/Sargent/266298.jpg
#   inflating: validation/validation/Sargent/266305.jpg
#   inflating: validation/validation/Sargent/266306.jpg
#   inflating: validation/validation/Sargent/266309.jpg
#   inflating: validation/validation/Sargent/266312.jpg
#   inflating: validation/validation/Sargent/266319.jpg
#   inflating: validation/validation/Sargent/266355.jpg
#   inflating: validation/validation/Sargent/266359.jpg
#   inflating: validation/validation/Sargent/266368.jpg
#   inflating: validation/validation/Sargent/266375.jpg
#   inflating: validation/validation/Sargent/266385.jpg
#   inflating: validation/validation/Sargent/266391.jpg
#   inflating: validation/validation/Sargent/266407.jpg
#   inflating: validation/validation/Sargent/266409.jpg
#   inflating: validation/validation/Sargent/266422.jpg
#   inflating: validation/validation/Sargent/266424.jpg
#   inflating: validation/validation/Sargent/266429.jpg
#   inflating: validation/validation/Sargent/9223372032559840631.jpg
#   inflating: validation/validation/Sargent/9223372032559840707.jpg
#   inflating: validation/validation/VanGogh/205655.jpg
#   inflating: validation/validation/VanGogh/205684.jpg
#   inflating: validation/validation/VanGogh/205688.jpg
#   inflating: validation/validation/VanGogh/205754.jpg
#   inflating: validation/validation/VanGogh/205762.jpg
#   inflating: validation/validation/VanGogh/205820.jpg
#   inflating: validation/validation/VanGogh/205846.jpg
#   inflating: validation/validation/VanGogh/205858.jpg
#   inflating: validation/validation/VanGogh/205881.jpg
#   inflating: validation/validation/VanGogh/205893.jpg
#   inflating: validation/validation/VanGogh/205918.jpg
#   inflating: validation/validation/VanGogh/205950.jpg
#   inflating: validation/validation/VanGogh/205968.jpg
#   inflating: validation/validation/VanGogh/205994.jpg
#   inflating: validation/validation/VanGogh/206027.jpg
#   inflating: validation/validation/VanGogh/206077.jpg
#   inflating: validation/validation/VanGogh/206146.jpg
#   inflating: validation/validation/VanGogh/206151.jpg
#   inflating: validation/validation/VanGogh/206175.jpg
#   inflating: validation/validation/VanGogh/206177.jpg
#   inflating: validation/validation/VanGogh/206204.jpg
#   inflating: validation/validation/VanGogh/206253.jpg
#   inflating: validation/validation/VanGogh/206260.jpg
#   inflating: validation/validation/VanGogh/206270.jpg
#   inflating: validation/validation/VanGogh/206282.jpg
#   inflating: validation/validation/VanGogh/206287.jpg
#   inflating: validation/validation/VanGogh/206289.jpg
#   inflating: validation/validation/VanGogh/206322.jpg
#   inflating: validation/validation/VanGogh/206326.jpg
#   inflating: validation/validation/VanGogh/206354.jpg
#   inflating: validation/validation/VanGogh/206386.jpg
#   inflating: validation/validation/VanGogh/206398.jpg
#   inflating: validation/validation/VanGogh/206449.jpg
#   inflating: validation/validation/VanGogh/206451.jpg
#   inflating: validation/validation/VanGogh/206478.jpg
#   inflating: validation/validation/VanGogh/206516.jpg
#   inflating: validation/validation/VanGogh/206523.jpg
#   inflating: validation/validation/VanGogh/206539.jpg
#   inflating: validation/validation/VanGogh/206554.jpg
#   inflating: validation/validation/VanGogh/206555.jpg
#   inflating: validation/validation/VanGogh/206556.jpg
#   inflating: validation/validation/VanGogh/206580.jpg
#   inflating: validation/validation/VanGogh/206589.jpg
#   inflating: validation/validation/VanGogh/206611.jpg
#   inflating: validation/validation/VanGogh/206619.jpg
#   inflating: validation/validation/VanGogh/206650.jpg
#   inflating: validation/validation/VanGogh/206665.jpg
#   inflating: validation/validation/VanGogh/206699.jpg
#   inflating: validation/validation/VanGogh/206719.jpg
#   inflating: validation/validation/VanGogh/206747.jpg
#   inflating: validation/validation/VanGogh/206748.jpg
#   inflating: validation/validation/VanGogh/206760.jpg
#   inflating: validation/validation/VanGogh/206765.jpg
#   inflating: validation/validation/VanGogh/206772.jpg
#   inflating: validation/validation/VanGogh/206807.jpg
#   inflating: validation/validation/VanGogh/206824.jpg
#   inflating: validation/validation/VanGogh/206840.jpg
#   inflating: validation/validation/VanGogh/206842.jpg
#   inflating: validation/validation/VanGogh/206844.jpg
#   inflating: validation/validation/VanGogh/206861.jpg
#   inflating: validation/validation/VanGogh/206888.jpg
#   inflating: validation/validation/VanGogh/206900.jpg
#   inflating: validation/validation/VanGogh/206927.jpg
#   inflating: validation/validation/VanGogh/206930.jpg
#   inflating: validation/validation/VanGogh/206935.jpg
#   inflating: validation/validation/VanGogh/206940.jpg
#   inflating: validation/validation/VanGogh/206964.jpg
#   inflating: validation/validation/VanGogh/206969.jpg
#   inflating: validation/validation/VanGogh/206980.jpg
#   inflating: validation/validation/VanGogh/206992.jpg
#   inflating: validation/validation/VanGogh/207003.jpg
#   inflating: validation/validation/VanGogh/207013.jpg
#   inflating: validation/validation/VanGogh/207014.jpg
#   inflating: validation/validation/VanGogh/207037.jpg
#   inflating: validation/validation/VanGogh/207047.jpg
#   inflating: validation/validation/VanGogh/207110.jpg
#   inflating: validation/validation/VanGogh/207112.jpg
#   inflating: validation/validation/VanGogh/207124.jpg
#   inflating: validation/validation/VanGogh/207187.jpg
#   inflating: validation/validation/VanGogh/207230.jpg
#   inflating: validation/validation/VanGogh/207263.jpg
#   inflating: validation/validation/VanGogh/207285.jpg
#   inflating: validation/validation/VanGogh/207292.jpg
#   inflating: validation/validation/VanGogh/207302.jpg
#   inflating: validation/validation/VanGogh/207324.jpg
#   inflating: validation/validation/VanGogh/207367.jpg
#   inflating: validation/validation/VanGogh/207391.jpg
#   inflating: validation/validation/VanGogh/207393.jpg
#   inflating: validation/validation/VanGogh/207412.jpg
#   inflating: validation/validation/VanGogh/207423.jpg
#   inflating: validation/validation/VanGogh/207430.jpg
#   inflating: validation/validation/VanGogh/207439.jpg
#   inflating: validation/validation/VanGogh/207442.jpg
#   inflating: validation/validation/VanGogh/207443.jpg
#   inflating: validation/validation/VanGogh/207446.jpg
#   inflating: validation/validation/VanGogh/207471.jpg
#   inflating: validation/validation/VanGogh/207486.jpg
#   inflating: validation/validation/VanGogh/207542.jpg
#   inflating: validation/validation/VanGogh/9223372032559834926.jpg

# %%
import numpy as np
import pandas as pd
import os
import torchvision
import torch.nn as nn
from torchvision.datasets import ImageFolder
from torchvision.transforms import Compose, Resize, ToTensor
from torch.utils.data import DataLoader, random_split, ConcatDataset
from torch import Generator
import torch
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import random
import itertools
import time
import copy
from torchvision.models import ResNet50_Weights
from torch.nn import Module
from torchvision import models
import torch.optim as optim
import seaborn as sns
import torchvision
import torch.nn as nn
from torch import manual_seed as torch_manual_seed
from torch.cuda import max_memory_allocated, set_device, manual_seed_all
from torch.backends import cudnn

# %%
def setup_seed(seed):
    torch_manual_seed(seed)
    manual_seed_all(seed)
    np.random.seed(seed)
    random.seed(seed)
    cudnn.deterministic = True

SEED = 6050
setup_seed(SEED)

# %%
artists = ['Cezanne', 'Degas', 'Gauguin', 'Hassam', 'Matisse', 'Monet', 'Pissarro', 'Renoir', 'Sargent', 'VanGogh']
artists = os.listdir('training/training')

# %%
transformation = Compose([
    Resize((256,256)),
    ToTensor()
])
transformation_train = Compose([
    torchvision.transforms.Resize((256,256)),
    torchvision.transforms.ColorJitter(hue=.05, saturation=.05),
    torchvision.transforms.RandomHorizontalFlip(),
    torchvision.transforms.RandomRotation(20),
    ToTensor()
])

image_datasets = {}
image_datasets['training'] = ImageFolder(f'/content/training/training', transform=transformation_train)
image_datasets['validation'] = ImageFolder(f'/content/validation/validation', transform=transformation)

size_all_validation = len(image_datasets['validation'])
size_test_from_validation = int(size_all_validation * 0.5)
size_validation = size_all_validation - size_test_from_validation

image_datasets['validation'], image_datasets['testing'] = random_split(image_datasets['validation'], [size_validation, size_test_from_validation], generator=Generator().manual_seed(SEED))

BS = 32
dataloaders = {x: DataLoader(image_datasets[x], batch_size=BS, shuffle=True) for x in ['training', 'validation', 'testing']}

dataset_sizes = {x: len(image_datasets[x]) for x in ['training', 'validation', 'testing']}
print(dataset_sizes)

# set the device
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# {'training': 3988, 'validation': 495, 'testing': 495}
# cuda:0

# %% [markdown]
# ## Model 1: ResNet50

# %%
# define the model to have the pre-trained resnet 50 parameters
model1 = torchvision.models.resnet50(weights=ResNet50_Weights.DEFAULT)
# freeze all of the parameters in the model
for param in model1.parameters():
  param.requires_grad = False
# unfreeze the parameters in the last residual block of the architecture
for name, param in model1.named_parameters():
  for i in [4]:
    if name.startswith(f'layer{i}'):
      param.requires_grad = True
# EDIT DROPOUT RATE HERE (dropout actually doesn't help here, so let's use L2 regularization instead)
DO = 0.0
# construct the fully connected head which will receive the flattened convolutional output
model1.fc = nn.Sequential(
               nn.Linear(2048, 512),
               nn.BatchNorm1d(512),
               nn.ReLU(inplace=True),
               nn.Dropout(DO),
               
               nn.Linear(512, 128),
               nn.BatchNorm1d(128),
               nn.ReLU(inplace=True),
               nn.Dropout(DO),

               nn.Linear(128, len(artists)))

# Print the named parameters to confirm that the correct ones are frozen and unfrozen
for name, param in model1.named_parameters():
    print(name, param.requires_grad)

# load the model to device
model1 = model1.to(device)
# Out:
# conv1.weight False
# bn1.weight False
# bn1.bias False
# layer1.0.conv1.weight False
# layer1.0.bn1.weight False
# layer1.0.bn1.bias False
# layer1.0.conv2.weight False
# layer1.0.bn2.weight False
# layer1.0.bn2.bias False
# layer1.0.conv3.weight False
# layer1.0.bn3.weight False
# layer1.0.bn3.bias False
# layer1.0.downsample.0.weight False
# layer1.0.downsample.1.weight False
# layer1.0.downsample.1.bias False
# layer1.1.conv1.weight False
# layer1.1.bn1.weight False
# layer1.1.bn1.bias False
# layer1.1.conv2.weight False
# layer1.1.bn2.weight False
# layer1.1.bn2.bias False
# layer1.1.conv3.weight False
# layer1.1.bn3.weight False
# layer1.1.bn3.bias False
# layer1.2.conv1.weight False
# layer1.2.bn1.weight False
# layer1.2.bn1.bias False
# layer1.2.conv2.weight False
# layer1.2.bn2.weight False
# layer1.2.bn2.bias False
# layer1.2.conv3.weight False
# layer1.2.bn3.weight False
# layer1.2.bn3.bias False
# layer2.0.conv1.weight False
# layer2.0.bn1.weight False
# layer2.0.bn1.bias False
# layer2.0.conv2.weight False
# layer2.0.bn2.weight False
# layer2.0.bn2.bias False
# layer2.0.conv3.weight False
# layer2.0.bn3.weight False
# layer2.0.bn3.bias False
# layer2.0.downsample.0.weight False
# layer2.0.downsample.1.weight False
# layer2.0.downsample.1.bias False
# layer2.1.conv1.weight False
# layer2.1.bn1.weight False
# layer2.1.bn1.bias False
# layer2.1.conv2.weight False
# layer2.1.bn2.weight False
# layer2.1.bn2.bias False
# layer2.1.conv3.weight False
# layer2.1.bn3.weight False
# layer2.1.bn3.bias False
# layer2.2.conv1.weight False
# layer2.2.bn1.weight False
# layer2.2.bn1.bias False
# layer2.2.conv2.weight False
# layer2.2.bn2.weight False
# layer2.2.bn2.bias False
# layer2.2.conv3.weight False
# layer2.2.bn3.weight False
# layer2.2.bn3.bias False
# layer2.3.conv1.weight False
# layer2.3.bn1.weight False
# layer2.3.bn1.bias False
# layer2.3.conv2.weight False
# layer2.3.bn2.weight False
# layer2.3.bn2.bias False
# layer2.3.conv3.weight False
# layer2.3.bn3.weight False
# layer2.3.bn3.bias False
# layer3.0.conv1.weight False
# layer3.0.bn1.weight False
# layer3.0.bn1.bias False
# layer3.0.conv2.weight False
# layer3.0.bn2.weight False
# layer3.0.bn2.bias False
# layer3.0.conv3.weight False
# layer3.0.bn3.weight False
# layer3.0.bn3.bias False
# layer3.0.downsample.0.weight False
# layer3.0.downsample.1.weight False
# layer3.0.downsample.1.bias False
# layer3.1.conv1.weight False
# layer3.1.bn1.weight False
# layer3.1.bn1.bias False
# layer3.1.conv2.weight False
# layer3.1.bn2.weight False
# layer3.1.bn2.bias False
# layer3.1.conv3.weight False
# layer3.1.bn3.weight False
# layer3.1.bn3.bias False
# layer3.2.conv1.weight False
# layer3.2.bn1.weight False
# layer3.2.bn1.bias False
# layer3.2.conv2.weight False
# layer3.2.bn2.weight False
# layer3.2.bn2.bias False
# layer3.2.conv3.weight False
# layer3.2.bn3.weight False
# layer3.2.bn3.bias False
# layer3.3.conv1.weight False
# layer3.3.bn1.weight False
# layer3.3.bn1.bias False
# layer3.3.conv2.weight False
# layer3.3.bn2.weight False
# layer3.3.bn2.bias False
# layer3.3.conv3.weight False
# layer3.3.bn3.weight False
# layer3.3.bn3.bias False
# layer3.4.conv1.weight False
# layer3.4.bn1.weight False
# layer3.4.bn1.bias False
# layer3.4.conv2.weight False
# layer3.4.bn2.weight False
# layer3.4.bn2.bias False
# layer3.4.conv3.weight False
# layer3.4.bn3.weight False
# layer3.4.bn3.bias False
# layer3.5.conv1.weight False
# layer3.5.bn1.weight False
# layer3.5.bn1.bias False
# layer3.5.conv2.weight False
# layer3.5.bn2.weight False
# layer3.5.bn2.bias False
# layer3.5.conv3.weight False
# layer3.5.bn3.weight False
# layer3.5.bn3.bias False
# layer4.0.conv1.weight False
# layer4.0.bn1.weight False
# layer4.0.bn1.bias False
# layer4.0.conv2.weight False
# layer4.0.bn2.weight False
# layer4.0.bn2.bias False
# layer4.0.conv3.weight False
# layer4.0.bn3.weight False
# layer4.0.bn3.bias False
# layer4.0.downsample.0.weight False
# layer4.0.downsample.1.weight False
# layer4.0.downsample.1.bias False
# layer4.1.conv1.weight False
# layer4.1.bn1.weight False
# layer4.1.bn1.bias False
# layer4.1.conv2.weight False
# layer4.1.bn2.weight False
# layer4.1.bn2.bias False
# layer4.1.conv3.weight False
# layer4.1.bn3.weight False
# layer4.1.bn3.bias False
# layer4.2.conv1.weight False
# layer4.2.bn1.weight False
# layer4.2.bn1.bias False
# layer4.2.conv2.weight False
# layer4.2.bn2.weight False
# layer4.2.bn2.bias False
# layer4.2.conv3.weight False
# layer4.2.bn3.weight False
# layer4.2.bn3.bias False
# fc.weight False
# fc.bias False

# %%
path = f'/content/drive/My Drive/resnetModel.pt'
model1.load_state_dict(torch.load(path))
# Out:
# <All keys matched successfully>

# %% [markdown]
# ## Model 2: EfficientNet

# %%
# define the model training function
def train_model(model, criterion, optimizer, num_epochs=25):
    # initialize the start time
    since = time.time()

    # initialize the best weight configuration and accuracy of the model
    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0

    # initialize the lists that will store the accuracies and losses across the epochs
    train_accs = []
    val_accs = []
    train_losses = []
    val_losses = []

    # iterate over the epochs
    for epoch in range(num_epochs):
        print(f'Epoch {epoch+1}/{num_epochs}')
        print('-' * 10)

        # each epoch has a training and validation phase
        for phase in ['training', 'validation']:
            if phase == 'training':
                model.train()  # set model to training mode
            else:
                model.eval()   # set model to evaluate mode

            # initialize the running losses and corrects
            running_loss = 0.0
            running_corrects = 0

            # iterate over the data
            for inputs, labels in dataloaders[phase]:
                inputs = inputs.to(device)
                labels = labels.to(device)

                # zero the parameter gradients
                optimizer.zero_grad()

                # forward pass
                # track history if only in train
                with torch.set_grad_enabled(phase == 'training'):
                    outputs = model(inputs)
                    _, preds = torch.max(outputs, 1)
                    loss = criterion(outputs, labels)

                    # backward pass
                    # optimize only if in training phase
                    if phase == 'training':
                        loss.backward()
                        optimizer.step()

                # calculate and update epoch statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)

            epoch_loss = running_loss / dataset_sizes[phase]
            epoch_acc = running_corrects.double() / dataset_sizes[phase]

            # print epoch performance statistics
            print(f'{phase} Loss: {epoch_loss:.4f} Acc: {epoch_acc:.4f}')

            # store epoch performance statistics
            if phase == 'training':
              train_accs.append(epoch_acc.item())
              train_losses.append(epoch_loss)
            else:
              val_accs.append(epoch_acc.item())
              val_losses.append(epoch_loss)

            # deep copy the model to reflect the best weight configuration
            if phase == 'validation' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())

        print()

    # print the training statistics
    time_elapsed = time.time() - since
    print(f'Training complete in {time_elapsed // 60:.0f}m {time_elapsed % 60:.0f}s')
    print(f'Best val Acc: {best_acc:4f}')

    # load best model weights
    model.load_state_dict(best_model_wts)
    return model, train_accs, train_losses, val_accs, val_losses

# %%
from torchvision.models import EfficientNet_B0_Weights

# Load the pre-trained EfficientNet-B0 model
model2 = torchvision.models.efficientnet_b0(weights=EfficientNet_B0_Weights.DEFAULT)

# Freeze all layers except the last two blocks
for name, param in model2.named_parameters():
    param.requires_grad = False

for name, param in model2.named_parameters():
  for i in [7,8]:
    if name.startswith(f'features.{i}'):
      param.requires_grad = True

# # Modify the fully connected head
DO = 0.
model2.classsifier = nn.Sequential(
    nn.Linear(1280, 256),
    nn.BatchNorm1d(256),
    nn.ReLU(inplace=True),
    nn.Dropout(DO),

    nn.Linear(256, 256),
    nn.BatchNorm1d(256),
    nn.ReLU(inplace=True),
    nn.Dropout(DO),

    nn.Linear(64, len(artists))
)

# Print the named parameters to confirm that the correct ones are frozen and unfrozen
for name, param in model2.named_parameters():
    print(name, param.requires_grad)

# Load the model to device
model2 = model2.to(device)
# Out:
# features.0.0.weight False
# features.0.1.weight False
# features.0.1.bias False
# features.1.0.block.0.0.weight False
# features.1.0.block.0.1.weight False
# features.1.0.block.0.1.bias False
# features.1.0.block.1.fc1.weight False
# features.1.0.block.1.fc1.bias False
# features.1.0.block.1.fc2.weight False
# features.1.0.block.1.fc2.bias False
# features.1.0.block.2.0.weight False
# features.1.0.block.2.1.weight False
# features.1.0.block.2.1.bias False
# features.2.0.block.0.0.weight False
# features.2.0.block.0.1.weight False
# features.2.0.block.0.1.bias False
# features.2.0.block.1.0.weight False
# features.2.0.block.1.1.weight False
# features.2.0.block.1.1.bias False
# features.2.0.block.2.fc1.weight False
# features.2.0.block.2.fc1.bias False
# features.2.0.block.2.fc2.weight False
# features.2.0.block.2.fc2.bias False
# features.2.0.block.3.0.weight False
# features.2.0.block.3.1.weight False
# features.2.0.block.3.1.bias False
# features.2.1.block.0.0.weight False
# features.2.1.block.0.1.weight False
# features.2.1.block.0.1.bias False
# features.2.1.block.1.0.weight False
# features.2.1.block.1.1.weight False
# features.2.1.block.1.1.bias False
# features.2.1.block.2.fc1.weight False
# features.2.1.block.2.fc1.bias False
# features.2.1.block.2.fc2.weight False
# features.2.1.block.2.fc2.bias False
# features.2.1.block.3.0.weight False
# features.2.1.block.3.1.weight False
# features.2.1.block.3.1.bias False
# features.3.0.block.0.0.weight False
# features.3.0.block.0.1.weight False
# features.3.0.block.0.1.bias False
# features.3.0.block.1.0.weight False
# features.3.0.block.1.1.weight False
# features.3.0.block.1.1.bias False
# features.3.0.block.2.fc1.weight False
# features.3.0.block.2.fc1.bias False
# features.3.0.block.2.fc2.weight False
# features.3.0.block.2.fc2.bias False
# features.3.0.block.3.0.weight False
# features.3.0.block.3.1.weight False
# features.3.0.block.3.1.bias False
# features.3.1.block.0.0.weight False
# features.3.1.block.0.1.weight False
# features.3.1.block.0.1.bias False
# features.3.1.block.1.0.weight False
# features.3.1.block.1.1.weight False
# features.3.1.block.1.1.bias False
# features.3.1.block.2.fc1.weight False
# features.3.1.block.2.fc1.bias False
# features.3.1.block.2.fc2.weight False
# features.3.1.block.2.fc2.bias False
# features.3.1.block.3.0.weight False
# features.3.1.block.3.1.weight False
# features.3.1.block.3.1.bias False
# features.4.0.block.0.0.weight False
# features.4.0.block.0.1.weight False
# features.4.0.block.0.1.bias False
# features.4.0.block.1.0.weight False
# features.4.0.block.1.1.weight False
# features.4.0.block.1.1.bias False
# features.4.0.block.2.fc1.weight False
# features.4.0.block.2.fc1.bias False
# features.4.0.block.2.fc2.weight False
# features.4.0.block.2.fc2.bias False
# features.4.0.block.3.0.weight False
# features.4.0.block.3.1.weight False
# features.4.0.block.3.1.bias False
# features.4.1.block.0.0.weight False
# features.4.1.block.0.1.weight False
# features.4.1.block.0.1.bias False
# features.4.1.block.1.0.weight False
# features.4.1.block.1.1.weight False
# features.4.1.block.1.1.bias False
# features.4.1.block.2.fc1.weight False
# features.4.1.block.2.fc1.bias False
# features.4.1.block.2.fc2.weight False
# features.4.1.block.2.fc2.bias False
# features.4.1.block.3.0.weight False
# features.4.1.block.3.1.weight False
# features.4.1.block.3.1.bias False
# features.4.2.block.0.0.weight False
# features.4.2.block.0.1.weight False
# features.4.2.block.0.1.bias False
# features.4.2.block.1.0.weight False
# features.4.2.block.1.1.weight False
# features.4.2.block.1.1.bias False
# features.4.2.block.2.fc1.weight False
# features.4.2.block.2.fc1.bias False
# features.4.2.block.2.fc2.weight False
# features.4.2.block.2.fc2.bias False
# features.4.2.block.3.0.weight False
# features.4.2.block.3.1.weight False
# features.4.2.block.3.1.bias False
# features.5.0.block.0.0.weight False
# features.5.0.block.0.1.weight False
# features.5.0.block.0.1.bias False
# features.5.0.block.1.0.weight False
# features.5.0.block.1.1.weight False
# features.5.0.block.1.1.bias False
# features.5.0.block.2.fc1.weight False
# features.5.0.block.2.fc1.bias False
# features.5.0.block.2.fc2.weight False
# features.5.0.block.2.fc2.bias False
# features.5.0.block.3.0.weight False
# features.5.0.block.3.1.weight False
# features.5.0.block.3.1.bias False
# features.5.1.block.0.0.weight False
# features.5.1.block.0.1.weight False
# features.5.1.block.0.1.bias False
# features.5.1.block.1.0.weight False
# features.5.1.block.1.1.weight False
# features.5.1.block.1.1.bias False
# features.5.1.block.2.fc1.weight False
# features.5.1.block.2.fc1.bias False
# features.5.1.block.2.fc2.weight False
# features.5.1.block.2.fc2.bias False
# features.5.1.block.3.0.weight False
# features.5.1.block.3.1.weight False
# features.5.1.block.3.1.bias False
# features.5.2.block.0.0.weight False
# features.5.2.block.0.1.weight False
# features.5.2.block.0.1.bias False
# features.5.2.block.1.0.weight False
# features.5.2.block.1.1.weight False
# features.5.2.block.1.1.bias False
# features.5.2.block.2.fc1.weight False
# features.5.2.block.2.fc1.bias False
# features.5.2.block.2.fc2.weight False
# features.5.2.block.2.fc2.bias False
# features.5.2.block.3.0.weight False
# features.5.2.block.3.1.weight False
# features.5.2.block.3.1.bias False
# features.6.0.block.0.0.weight False
# features.6.0.block.0.1.weight False
# features.6.0.block.0.1.bias False
# features.6.0.block.1.0.weight False
# features.6.0.block.1.1.weight False
# features.6.0.block.1.1.bias False
# features.6.0.block.2.fc1.weight False
# features.6.0.block.2.fc1.bias False
# features.6.0.block.2.fc2.weight False
# features.6.0.block.2.fc2.bias False
# features.6.0.block.3.0.weight False
# features.6.0.block.3.1.weight False
# features.6.0.block.3.1.bias False
# features.6.1.block.0.0.weight False
# features.6.1.block.0.1.weight False
# features.6.1.block.0.1.bias False
# features.6.1.block.1.0.weight False
# features.6.1.block.1.1.weight False
# features.6.1.block.1.1.bias False
# features.6.1.block.2.fc1.weight False
# features.6.1.block.2.fc1.bias False
# features.6.1.block.2.fc2.weight False
# features.6.1.block.2.fc2.bias False
# features.6.1.block.3.0.weight False
# features.6.1.block.3.1.weight False
# features.6.1.block.3.1.bias False
# features.6.2.block.0.0.weight False
# features.6.2.block.0.1.weight False
# features.6.2.block.0.1.bias False
# features.6.2.block.1.0.weight False
# features.6.2.block.1.1.weight False
# features.6.2.block.1.1.bias False
# features.6.2.block.2.fc1.weight False
# features.6.2.block.2.fc1.bias False
# features.6.2.block.2.fc2.weight False
# features.6.2.block.2.fc2.bias False
# features.6.2.block.3.0.weight False
# features.6.2.block.3.1.weight False
# features.6.2.block.3.1.bias False
# features.6.3.block.0.0.weight False
# features.6.3.block.0.1.weight False
# features.6.3.block.0.1.bias False
# features.6.3.block.1.0.weight False
# features.6.3.block.1.1.weight False
# features.6.3.block.1.1.bias False
# features.6.3.block.2.fc1.weight False
# features.6.3.block.2.fc1.bias False
# features.6.3.block.2.fc2.weight False
# features.6.3.block.2.fc2.bias False
# features.6.3.block.3.0.weight False
# features.6.3.block.3.1.weight False
# features.6.3.block.3.1.bias False
# features.7.0.block.0.0.weight True
# features.7.0.block.0.1.weight True
# features.7.0.block.0.1.bias True
# features.7.0.block.1.0.weight True
# features.7.0.block.1.1.weight True
# features.7.0.block.1.1.bias True
# features.7.0.block.2.fc1.weight True
# features.7.0.block.2.fc1.bias True
# features.7.0.block.2.fc2.weight True
# features.7.0.block.2.fc2.bias True
# features.7.0.block.3.0.weight True
# features.7.0.block.3.1.weight True
# features.7.0.block.3.1.bias True
# features.8.0.weight True
# features.8.1.weight True
# features.8.1.bias True
# classifier.1.weight False
# classifier.1.bias False
# classsifier.0.weight True
# classsifier.0.bias True
# classsifier.1.weight True
# classsifier.1.bias True
# classsifier.4.weight True
# classsifier.4.bias True
# classsifier.5.weight True
# classsifier.5.bias True
# classsifier.8.weight True
# classsifier.8.bias True

# %%
# define the loss function
criterion = nn.CrossEntropyLoss()

# EDIT LEARNING RATE HERE (tune 0.01, 0.001, 0.0001 with batch size of 16)
LR = 0.0005 # (fixed)

# EDIT WEIGHT DECAY (L2 REGULARIZATION) HERE (tune 1e-5, 1e-4, 1e-3)
WD = 1e-5

# set the optimizer for the parameters of the whole model
optimizer = optim.Adam(filter(lambda p: p.requires_grad, model2.parameters()), lr=LR, weight_decay=WD)

# %%
# train the model for the desired number of epochs
model2, train_accs, train_losses, val_accs, val_losses = train_model(model2, criterion, optimizer, num_epochs=10)
# Out:
# Epoch 1/10
# ----------
# training Loss: 2.7184 Acc: 0.4975
# validation Loss: 1.1358 Acc: 0.6869
#
# Epoch 2/10
# ----------

# %%
# path = f'/content/drive/My Drive/efficientnetModel.pt'
# model2.load_state_dict(torch.load(path))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-f39a26685e4b> in <cell line: 2>()
#       1 path = f'/content/drive/My Drive/efficientnetModel.pt'
# ----> 2 model2.load_state_dict(torch.load(path))
#
# NameError: name 'model2' is not defined

# %% [markdown]
# ## Model 3: GoogLeNet

# %%
# !pip install googlenet_pytorch
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting googlenet_pytorch
#   Downloading googlenet_pytorch-0.3.0-py2.py3-none-any.whl (13 kB)
# Requirement already satisfied: torch in /usr/local/lib/python3.9/dist-packages (from googlenet_pytorch) (2.0.0+cu118)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.9/dist-packages (from torch->googlenet_pytorch) (2.0.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.9/dist-packages (from torch->googlenet_pytorch) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.9/dist-packages (from torch->googlenet_pytorch) (3.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from torch->googlenet_pytorch) (3.11.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.9/dist-packages (from torch->googlenet_pytorch) (3.1.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.9/dist-packages (from torch->googlenet_pytorch) (4.5.0)
# Requirement already satisfied: lit in /usr/local/lib/python3.9/dist-packages (from triton==2.0.0->torch->googlenet_pytorch) (16.0.1)
# Requirement already satisfied: cmake in /usr/local/lib/python3.9/dist-packages (from triton==2.0.0->torch->googlenet_pytorch) (3.25.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/dist-packages (from jinja2->torch->googlenet_pytorch) (2.1.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.9/dist-packages (from sympy->torch->googlenet_pytorch) (1.3.0)
# Installing collected packages: googlenet_pytorch
# Successfully installed googlenet_pytorch-0.3.0

# %%
#pip install googlenet_pytorch
# batch_size = 32, learning_rate = 0.0005, weight_decay = 1e-5, Data Augmentation

from googlenet_pytorch import GoogLeNet
model_google = GoogLeNet.from_pretrained("googlenet")

# freeze all of the parameters in the model
for param in model_google.parameters():
    param.requires_grad = False
# unfreeze the parameters in the last residual block of the architecture
for name, param in model_google.named_parameters():
    for i in [5]:
        if name.startswith(f'inception{5}') or name.startswith('aux'):
            param.requires_grad = True

# EDIT DROPOUT RATE HERE (dropout actually doesn't help here, so let's use L2 regularization instead)
DO = 0.0
# construct the fully connected head which will receive the flattened convolutional output

'''
The final layer of GoogLeNet is a global average pooling layer that reduces the spatial 
dimensions of the feature maps to 1x1 and produces a tensor of size (1, 1024).
''' 
model_google.fc = nn.Sequential(
               nn.Linear(1024, 256), # 2048 -> 1024
               nn.BatchNorm1d(256),
               nn.ReLU(inplace=True),
               nn.Dropout(DO),
               
               nn.Linear(256, 64),
               nn.BatchNorm1d(64),
               nn.ReLU(inplace=True),
               nn.Dropout(DO),

               nn.Linear(64, len(artists)))

# print all the named parameters in the model to confirm that the correct ones are frozen and unfrozen
for name, param in model_google.named_parameters():
    print(name, param.requires_grad)

model_google = model_google.to(device)
model_google.aux_logits = False ### NEVER REMOVE THIS LINE
# Out:
# Loaded pretrained weights for googlenet
# conv1.conv.weight False
# conv1.bn.weight False
# conv1.bn.bias False
# conv2.conv.weight False
# conv2.bn.weight False
# conv2.bn.bias False
# conv3.conv.weight False
# conv3.bn.weight False
# conv3.bn.bias False
# inception3a.branch1.conv.weight False
# inception3a.branch1.bn.weight False
# inception3a.branch1.bn.bias False
# inception3a.branch2.0.conv.weight False
# inception3a.branch2.0.bn.weight False
# inception3a.branch2.0.bn.bias False
# inception3a.branch2.1.conv.weight False
# inception3a.branch2.1.bn.weight False
# inception3a.branch2.1.bn.bias False
# inception3a.branch3.0.conv.weight False
# inception3a.branch3.0.bn.weight False
# inception3a.branch3.0.bn.bias False
# inception3a.branch3.1.conv.weight False
# inception3a.branch3.1.bn.weight False
# inception3a.branch3.1.bn.bias False
# inception3a.branch4.1.conv.weight False
# inception3a.branch4.1.bn.weight False
# inception3a.branch4.1.bn.bias False
# inception3b.branch1.conv.weight False
# inception3b.branch1.bn.weight False
# inception3b.branch1.bn.bias False
# inception3b.branch2.0.conv.weight False
# inception3b.branch2.0.bn.weight False
# inception3b.branch2.0.bn.bias False
# inception3b.branch2.1.conv.weight False
# inception3b.branch2.1.bn.weight False
# inception3b.branch2.1.bn.bias False
# inception3b.branch3.0.conv.weight False
# inception3b.branch3.0.bn.weight False
# inception3b.branch3.0.bn.bias False
# inception3b.branch3.1.conv.weight False
# inception3b.branch3.1.bn.weight False
# inception3b.branch3.1.bn.bias False
# inception3b.branch4.1.conv.weight False
# inception3b.branch4.1.bn.weight False
# inception3b.branch4.1.bn.bias False
# inception4a.branch1.conv.weight False
# inception4a.branch1.bn.weight False
# inception4a.branch1.bn.bias False
# inception4a.branch2.0.conv.weight False
# inception4a.branch2.0.bn.weight False
# inception4a.branch2.0.bn.bias False
# inception4a.branch2.1.conv.weight False
# inception4a.branch2.1.bn.weight False
# inception4a.branch2.1.bn.bias False
# inception4a.branch3.0.conv.weight False
# inception4a.branch3.0.bn.weight False
# inception4a.branch3.0.bn.bias False
# inception4a.branch3.1.conv.weight False
# inception4a.branch3.1.bn.weight False
# inception4a.branch3.1.bn.bias False
# inception4a.branch4.1.conv.weight False
# inception4a.branch4.1.bn.weight False
# inception4a.branch4.1.bn.bias False
# inception4b.branch1.conv.weight False
# inception4b.branch1.bn.weight False
# inception4b.branch1.bn.bias False
# inception4b.branch2.0.conv.weight False
# inception4b.branch2.0.bn.weight False
# inception4b.branch2.0.bn.bias False
# inception4b.branch2.1.conv.weight False
# inception4b.branch2.1.bn.weight False
# inception4b.branch2.1.bn.bias False
# inception4b.branch3.0.conv.weight False
# inception4b.branch3.0.bn.weight False
# inception4b.branch3.0.bn.bias False
# inception4b.branch3.1.conv.weight False
# inception4b.branch3.1.bn.weight False
# inception4b.branch3.1.bn.bias False
# inception4b.branch4.1.conv.weight False
# inception4b.branch4.1.bn.weight False
# inception4b.branch4.1.bn.bias False
# inception4c.branch1.conv.weight False
# inception4c.branch1.bn.weight False
# inception4c.branch1.bn.bias False
# inception4c.branch2.0.conv.weight False
# inception4c.branch2.0.bn.weight False
# inception4c.branch2.0.bn.bias False
# inception4c.branch2.1.conv.weight False
# inception4c.branch2.1.bn.weight False
# inception4c.branch2.1.bn.bias False
# inception4c.branch3.0.conv.weight False
# inception4c.branch3.0.bn.weight False
# inception4c.branch3.0.bn.bias False
# inception4c.branch3.1.conv.weight False
# inception4c.branch3.1.bn.weight False
# inception4c.branch3.1.bn.bias False
# inception4c.branch4.1.conv.weight False
# inception4c.branch4.1.bn.weight False
# inception4c.branch4.1.bn.bias False
# inception4d.branch1.conv.weight False
# inception4d.branch1.bn.weight False
# inception4d.branch1.bn.bias False
# inception4d.branch2.0.conv.weight False
# inception4d.branch2.0.bn.weight False
# inception4d.branch2.0.bn.bias False
# inception4d.branch2.1.conv.weight False
# inception4d.branch2.1.bn.weight False
# inception4d.branch2.1.bn.bias False
# inception4d.branch3.0.conv.weight False
# inception4d.branch3.0.bn.weight False
# inception4d.branch3.0.bn.bias False
# inception4d.branch3.1.conv.weight False
# inception4d.branch3.1.bn.weight False
# inception4d.branch3.1.bn.bias False
# inception4d.branch4.1.conv.weight False
# inception4d.branch4.1.bn.weight False
# inception4d.branch4.1.bn.bias False
# inception4e.branch1.conv.weight False
# inception4e.branch1.bn.weight False
# inception4e.branch1.bn.bias False
# inception4e.branch2.0.conv.weight False
# inception4e.branch2.0.bn.weight False
# inception4e.branch2.0.bn.bias False
# inception4e.branch2.1.conv.weight False
# inception4e.branch2.1.bn.weight False
# inception4e.branch2.1.bn.bias False
# inception4e.branch3.0.conv.weight False
# inception4e.branch3.0.bn.weight False
# inception4e.branch3.0.bn.bias False
# inception4e.branch3.1.conv.weight False
# inception4e.branch3.1.bn.weight False
# inception4e.branch3.1.bn.bias False
# inception4e.branch4.1.conv.weight False
# inception4e.branch4.1.bn.weight False
# inception4e.branch4.1.bn.bias False
# inception5a.branch1.conv.weight True
# inception5a.branch1.bn.weight True
# inception5a.branch1.bn.bias True
# inception5a.branch2.0.conv.weight True
# inception5a.branch2.0.bn.weight True
# inception5a.branch2.0.bn.bias True
# inception5a.branch2.1.conv.weight True
# inception5a.branch2.1.bn.weight True
# inception5a.branch2.1.bn.bias True
# inception5a.branch3.0.conv.weight True
# inception5a.branch3.0.bn.weight True
# inception5a.branch3.0.bn.bias True
# inception5a.branch3.1.conv.weight True
# inception5a.branch3.1.bn.weight True
# inception5a.branch3.1.bn.bias True
# inception5a.branch4.1.conv.weight True
# inception5a.branch4.1.bn.weight True
# inception5a.branch4.1.bn.bias True
# inception5b.branch1.conv.weight True
# inception5b.branch1.bn.weight True
# inception5b.branch1.bn.bias True
# inception5b.branch2.0.conv.weight True
# inception5b.branch2.0.bn.weight True
# inception5b.branch2.0.bn.bias True
# inception5b.branch2.1.conv.weight True
# inception5b.branch2.1.bn.weight True
# inception5b.branch2.1.bn.bias True
# inception5b.branch3.0.conv.weight True
# inception5b.branch3.0.bn.weight True
# inception5b.branch3.0.bn.bias True
# inception5b.branch3.1.conv.weight True
# inception5b.branch3.1.bn.weight True
# inception5b.branch3.1.bn.bias True
# inception5b.branch4.1.conv.weight True
# inception5b.branch4.1.bn.weight True
# inception5b.branch4.1.bn.bias True
# aux1.conv.conv.weight True
# aux1.conv.bn.weight True
# aux1.conv.bn.bias True
# aux1.fc1.weight True
# aux1.fc1.bias True
# aux1.fc2.weight True
# aux1.fc2.bias True
# aux2.conv.conv.weight True
# aux2.conv.bn.weight True
# aux2.conv.bn.bias True
# aux2.fc1.weight True
# aux2.fc1.bias True
# aux2.fc2.weight True
# aux2.fc2.bias True
# fc.0.weight True
# fc.0.bias True
# fc.1.weight True
# fc.1.bias True
# fc.4.weight True
# fc.4.bias True
# fc.5.weight True
# fc.5.bias True
# fc.8.weight True
# fc.8.bias True

# %%
# define the loss function
criterion = nn.CrossEntropyLoss()

# EDIT LEARNING RATE HERE (tune 0.01, 0.001, 0.0001 with batch size of 16)
LR = 0.0005 # (fixed)

# EDIT WEIGHT DECAY (L2 REGULARIZATION) HERE (tune 1e-5, 1e-4, 1e-3)
WD = 1e-5

# set the optimizer for the parameters of the whole model
optimizer = optim.Adam(filter(lambda p: p.requires_grad, model_google.parameters()), lr=LR, weight_decay=WD)

# %%
# train the model for the desired number of epochs
model3, train_accs, train_losses, val_accs, val_losses = train_model(model_google, criterion, optimizer, num_epochs=10)

# %%
# path = f'/content/drive/My Drive/googlenetModel.pt'
# model3.load_state_dict(torch.load(path))

# %% [markdown]
# ##**Final Ensemble**

# %%
# define the test loop
def ensemble_test_loop(dataloader, model1, model2, model3, loss_fn):
  # calculate the size of the dataset and the number of batches
  size = len(dataloader.dataset)
  num_batches = len(dataloader)

  # initialize the model performance metrics
  test_loss, correct = 0, 0

  # set model to evaluate model
  model1.eval()
  model2.eval()

  # iterate over the data and compute the performance metrics
  with torch.no_grad():
    for X, y in dataloader:
      X = X.to(device)
      y = y.to(device)
      pred1 = model1(X)
      pred2 = model2(X)
      pred = (pred1+pred2)/2
      test_loss += loss_fn(pred, y).item()
      correct += (pred.argmax(1) == y).type(torch.float).sum().item()

  test_loss /= num_batches
  correct /= size

  # print the performance metrics
  print(f"Test Error: \n Accuracy: {(100*correct):>0.1f}%, Avg loss: {test_loss:>8f} \n")

# define the loss function
loss_fn = nn.CrossEntropyLoss()

# evaluate the first model
ensemble_test_loop(dataloaders['testing'], model1, model2, loss_fn)
# Out:
# Test Error:
#  Accuracy: 85.7%, Avg loss: 0.552976
